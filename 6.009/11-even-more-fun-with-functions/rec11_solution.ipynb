# %% [markdown]
# Mastering algorithmic programming puzzles may be a good way to prepare for interviews at software companies, but some of the most common kinds of programming are much more mundane.  This recitation introduces the tools for one of them: scripting tasks that process text files in a standard file system.  There are a few distinct aspects of these tasks: crawling the file system, reading in the text files we find, computing interesting derived data sets from what we read, and outputting the results in new text files.  (The “reading in” part is common enough that it gets its own name, “parsing,” which we're also looking at in the context of programming languages in Labs 8 through 10.)
#
# We'll use a running example in this lecture.  Picture, if you will, this far-fetched scenario: It's the day after the final exam in an MIT class.  The staff have studiously collected all information on final grades in a spreadsheet, and it's time to upload the grade data to the MIT Online Grades System (OGS).  There's just one problem: their spreadsheet format doesn't quite match what OGS wants.  In fact, to satisfy the paranoid OGS, they will need to include some fields of student information that aren't even found in their spreadsheet.  Luckily, WebSIS provides a dump of that information, but in its own baroque text format.  We need to combine two data sets to produce a remixed text file in a different format.
#
# This scenario isn't so imaginary.  Often a TA gets stuck scrambling at the last minute, writing the scripting code to produce the final grade data.  Some day you could be that TA, and the Python examples from this lecture will give you a head start.
#
# Other examples abound throughout the life of a programmer, from analyzing laboratory data as a UROP to keeping the servers running as a software engineer at a big-name Internet company.
#
# # Parsing WebSIS Student Lists
#
# The file `generate.py` of the lecture code contains some functions for generating test data in various formats.  In class, we use student data created randomly by [a nifty web service](http://www.generatedata.com/).  We can ask for the data in the [JSON format](https://en.wikipedia.org/wiki/JSON), which Python conveniently accepts as code.  Then one of our functions outputs the data to a text file mimicking what WebSIS provides to instructors.
#
# To generate the example input files yourself, run
#
#       python3 generate.py
#
# Check out `websis.txt`.  It's an interesting puzzle to work through how to process WebSIS data into the natural Python data structures.  Many of the puzzles we've looked at in this class seem hard even when we try to compute answers ourselves on a blackboard.  In contrast, processing a text file often seems trivial at first, and yet we encounter all sorts of fiddly details in trying to write code that does it properly.

# %% [markdown]
# Here's a handy helper function.

# %%
def allCharactersIn(checkForThese, inThis):
    """Check if all characters of one string are also in the other string."""
    
    for ch in inThis:
        if not ch in checkForThese:
            return False
    return True

# %% [markdown]
# The next key ingredient will be processing the header line that has a whole bunch of dashes on it, indicating the boundaries of the different fields in the rows that follow.

# %%
def dashSpans(s):
    """Given a string of dashes and nondash characters, return the beginning of each sequence of dashes.
    The output is a list of the numeric positions of those first characters, within the string."""
    
    alreadyInDash = False
    output = []

    for i in range(len(s)):
        if not alreadyInDash and s[i] == '-':
            output.append(i)
        alreadyInDash = (s[i] == '-')

    return output

# %% [markdown]
# In the WebSIS format, when a field value is shorter than the total length allocated to the field, extra spaces appear.  Let's write a function to remove the extras.

# %%
def removeTrailing(s):
    """Return a string that omits trailing spaces and newlines."""
    for i in reversed(range(len(s))):
        # The following check succeeds on the _last_ nonspace character in the string.
        if s[i] != ' ' and s[i] != '\n':
            return s[:i+1]
    return ""

# %% [markdown]
# Now we can process the column headers.

# %%
def columnHeaders(s, spans):
    """Given the dash spans of a string, extract the column headers from a
    string standing for the immediately previous line in the file."""
    
    lastSpan = None
    output = []

    for span in spans:
        if lastSpan:
            output.append(removeTrailing(s[lastSpan:span]))
        lastSpan = span

    output.append(removeTrailing(s[lastSpan:]))
    return output

# %% [markdown]
# Next, here's how we can process one row of data.

# %%
def removeLeading(s):
    """Return a string that omits leading spaces and newlines."""
    for i in range(len(s)):
        if s[i] != ' ' and s[i] != '\n':
            return s[i:]
    return ""

def trim(s):
    """Remove both leading and trailing spaces and newlines."""
    return removeLeading(removeTrailing(s))

def readRow(spans, headers, s):
    """Given information on field spans and headers, process a single line of text
    into a dictionary with one field per header."""
    output = {}

    for i in range(len(spans)):
        if i < len(spans)-1:
            value = s[spans[i]:spans[i+1]]
        else:
            value = s[spans[i]:]
        output[headers[i]] = trim(value)

    return output

# %% [markdown]
# Finally, we tie it all together.

# %%
def parseWebsis(filename):
    """Read a single WebSIS student-enrollment record from the named file."""
    with open(filename, "r") as f:
        last_line = ""

        # Step 1: loop until we find a line of all spaces and dashes.
        # This is the header that defines which fields exist.
        for line in f:
            if allCharactersIn(" -\n", line) and not allCharactersIn(" \n", line):
                spans = dashSpans(line)
                headers = columnHeaders(last_line, spans)
                break
            last_line = line

        # Step 2: loop reading all of the data rows.
        rows = []
        for line in f:
            rows.append(readRow(spans, headers, line))

        return rows

# %%
websis = parseWebsis('websis.txt')
websis
# Out:
# [{'MIT ID': '920073587',
#   'Student Name': 'Martin, Odette Q.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk'},
#  {'MIT ID': '911887284',
#   'Student Name': 'Clarke, Cyrus G.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'orci.quis@dignissim.ca'},
#  {'MIT ID': '919043935',
#   'Student Name': 'Wolf, Omar B.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'dui@enim.ca'},
#  {'MIT ID': '924379468',
#   'Student Name': 'Wagner, Erin C.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'eu@Craseget.com'},
#  {'MIT ID': '911034657',
#   'Student Name': 'Melendez, Ora J.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'aliquet.vel@Vestibulum.org'},
#  {'MIT ID': '923259664',
#   'Student Name': 'Herring, Mark N.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'at@massa.net'},
#  {'MIT ID': '919240359',
#   'Student Name': 'Mcguire, Pearl E.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'in@iaculis.org'},
#  {'MIT ID': '929939788',
#   'Student Name': 'Richmond, Nola H.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'porttitor.eros@ametdapibus.com'},
#  {'MIT ID': '916427666',
#   'Student Name': 'Maddox, Shelly S.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'orci.tincidunt.adipiscing@lobortisrisusIn.org'},
#  {'MIT ID': '910950663',
#   'Student Name': 'Barlow, Hayes H.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Curabitur.egestas.nunc@erat.org'},
#  {'MIT ID': '910078438',
#   'Student Name': 'Craft, Freya G.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ante.ipsum@Phasellusat.edu'},
#  {'MIT ID': '921474764',
#   'Student Name': 'Acevedo, Evelyn Z.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'faucibus@elitNulla.edu'},
#  {'MIT ID': '924791290',
#   'Student Name': 'Mayer, Phelan J.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Nunc.ullamcorper@aceleifend.net'},
#  {'MIT ID': '928056570',
#   'Student Name': 'Hopkins, Haley K.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'dolor.Quisque.tincidunt@quisarcuvel.com'},
#  {'MIT ID': '919313842',
#   'Student Name': 'Bradford, Madonna A.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'turpis@milorem.ca'},
#  {'MIT ID': '926788143',
#   'Student Name': 'Slater, Callie F.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'semper.auctor.Mauris@Maurismagna.com'},
#  {'MIT ID': '926077323',
#   'Student Name': 'Parrish, Phyllis B.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'blandit@augue.ca'},
#  {'MIT ID': '916226812',
#   'Student Name': 'Crawford, Mari A.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'tellus.imperdiet@necmetus.net'},
#  {'MIT ID': '919045387',
#   'Student Name': 'Cole, Wanda D.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'dui.quis@pretiumneque.com'},
#  {'MIT ID': '922649174',
#   'Student Name': 'Sharp, Rama W.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'tristique.aliquet.Phasellus@dictumeuplacerat.ca'},
#  {'MIT ID': '912746757',
#   'Student Name': 'Durham, Claudia K.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'sit@duiSuspendisse.edu'},
#  {'MIT ID': '925857609',
#   'Student Name': 'Dillon, Nora K.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'pede.Nunc.sed@justoProin.co.uk'},
#  {'MIT ID': '923900426',
#   'Student Name': 'Wise, Ruby Z.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'eu.ultrices.sit@tempuseu.ca'},
#  {'MIT ID': '919272390',
#   'Student Name': 'Ramsey, Ora A.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Cras.pellentesque.Sed@ligulatortor.ca'},
#  {'MIT ID': '928129345',
#   'Student Name': 'Brady, Michelle H.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ut.nulla@Aliquam.edu'},
#  {'MIT ID': '922126085',
#   'Student Name': 'Horn, Tanner W.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'sem.Nulla@lacuspedesagittis.co.uk'},
#  {'MIT ID': '910548724',
#   'Student Name': 'Holcomb, Kerry L.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Integer.tincidunt.aliquam@enim.ca'},
#  {'MIT ID': '916213118',
#   'Student Name': 'Dawson, Germaine O.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'convallis.convallis@facilisi.edu'},
#  {'MIT ID': '912123189',
#   'Student Name': 'Delaney, Camille M.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Etiam.laoreet.libero@amet.org'},
#  {'MIT ID': '917018918',
#   'Student Name': 'Joseph, Linus T.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'pede@pharetrasedhendrerit.co.uk'},
#  {'MIT ID': '917047894',
#   'Student Name': 'Hogan, Aubrey E.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'congue.a@eudoloregestas.edu'},
#  {'MIT ID': '927370328',
#   'Student Name': 'Greene, Kibo E.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'gravida.Aliquam.tincidunt@nulla.ca'},
#  {'MIT ID': '927584384',
#   'Student Name': 'Alexander, Stuart B.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'vitae@Pellentesque.com'},
#  {'MIT ID': '914932036',
#   'Student Name': 'Rojas, Imogene D.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'inceptos@semperet.ca'},
#  {'MIT ID': '923792556',
#   'Student Name': 'Decker, Zane P.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'nec.cursus@arcuVestibulumante.net'},
#  {'MIT ID': '914454532',
#   'Student Name': 'Avery, Igor J.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'mauris.Morbi@aliquetnec.edu'},
#  {'MIT ID': '929805909',
#   'Student Name': 'Dixon, Xanthus K.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Donec.consectetuer.mauris@feugiat.co.uk'},
#  {'MIT ID': '913546432',
#   'Student Name': 'Foster, Tate K.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ultricies.sem.magna@scelerisquenequeNullam.edu'},
#  {'MIT ID': '914257871',
#   'Student Name': 'Pickett, Gage D.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Nulla@atauctorullamcorper.com'},
#  {'MIT ID': '915450751',
#   'Student Name': 'Holden, Rudyard B.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Nunc.laoreet@Aliquamrutrum.ca'},
#  {'MIT ID': '929604413',
#   'Student Name': 'Brennan, Macon D.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'a@acarcuNunc.org'},
#  {'MIT ID': '912098698',
#   'Student Name': 'Frank, Shoshana K.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Phasellus.fermentum@Proin.org'},
#  {'MIT ID': '921871638',
#   'Student Name': 'Mcmillan, Kuame R.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'dui.in.sodales@lorem.org'},
#  {'MIT ID': '927442120',
#   'Student Name': 'Reilly, Rylee L.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'nisl.Maecenas@justo.com'},
#  {'MIT ID': '915638652',
#   'Student Name': 'Hooper, Jack T.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'volutpat@quis.com'},
#  {'MIT ID': '911747225',
#   'Student Name': 'Bradley, Kathleen L.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'vitae.orci.Phasellus@turpis.com'},
#  {'MIT ID': '919338457',
#   'Student Name': 'Carroll, Bryar Y.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'odio@nonmassa.net'},
#  {'MIT ID': '913554650',
#   'Student Name': 'Ortega, Cain H.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Phasellus.at.augue@eu.co.uk'},
#  {'MIT ID': '911023764',
#   'Student Name': 'Donovan, Alexandra E',
#   'Course': '.  6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'vel@enimnonnisi.com'},
#  {'MIT ID': '914956808',
#   'Student Name': 'Fox, Orli J.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'orci@purusDuiselementum.ca'},
#  {'MIT ID': '925647999',
#   'Student Name': 'Bernard, Trevor V.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Pellentesque@eros.ca'},
#  {'MIT ID': '921185615',
#   'Student Name': 'Maynard, Plato B.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Mauris.non.dui@blanditatnisi.edu'},
#  {'MIT ID': '925479892',
#   'Student Name': 'Sosa, Sawyer B.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Fusce@vitae.ca'},
#  {'MIT ID': '914936944',
#   'Student Name': 'Sawyer, Serena R.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'malesuada.Integer@ornareplacerat.com'},
#  {'MIT ID': '917327533',
#   'Student Name': 'Lara, Fay P.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'id.ante@tellus.net'},
#  {'MIT ID': '929111850',
#   'Student Name': 'Hyde, Xerxes N.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'sem.Nulla@at.edu'},
#  {'MIT ID': '926668509',
#   'Student Name': 'Boyer, Whilemina I.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ut.nulla.Cras@nisi.org'},
#  {'MIT ID': '923753510',
#   'Student Name': 'Alvarez, Brock V.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'enim.diam.vel@fringillamilacinia.co.uk'},
#  {'MIT ID': '916490110',
#   'Student Name': 'Howard, Leandra A.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'et.commodo@elit.com'},
#  {'MIT ID': '917799882',
#   'Student Name': 'Phillips, Ruth P.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'nulla.Integer.urna@tortor.ca'},
#  {'MIT ID': '912115446',
#   'Student Name': 'Gonzales, Lane X.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'velit.Quisque@scelerisque.co.uk'},
#  {'MIT ID': '911053677',
#   'Student Name': 'Hurley, Kaseem D.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'aliquet.sem@non.co.uk'},
#  {'MIT ID': '928558858',
#   'Student Name': 'Webb, Edward D.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'odio.Aliquam@rhoncus.ca'},
#  {'MIT ID': '914299177',
#   'Student Name': 'Blackwell, Yoshi Z.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'non@Proinmi.edu'},
#  {'MIT ID': '921522341',
#   'Student Name': 'Fowler, Tad M.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'lorem.fringilla.ornare@non.com'},
#  {'MIT ID': '925048151',
#   'Student Name': 'Shannon, Yvette T.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ante@auctorMauris.edu'},
#  {'MIT ID': '917724027',
#   'Student Name': 'Calhoun, Myles G.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ullamcorper.Duis.at@netus.org'},
#  {'MIT ID': '913318146',
#   'Student Name': 'Bishop, Nayda Q.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'non.massa.non@Morbivehicula.org'},
#  {'MIT ID': '923397139',
#   'Student Name': 'Hogan, Brendan K.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Maecenas.mi@Etiamvestibulum.ca'},
#  {'MIT ID': '926139788',
#   'Student Name': 'Sutton, Warren E.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Quisque.porttitor.eros@enimMauris.ca'},
#  {'MIT ID': '927846295',
#   'Student Name': 'Buckley, Noelani P.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'consequat.purus.Maecenas@eratSed.com'},
#  {'MIT ID': '929898786',
#   'Student Name': 'Schultz, Malik J.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'mi@felis.edu'},
#  {'MIT ID': '912038146',
#   'Student Name': 'Stout, Dorothy B.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'orci@metus.edu'},
#  {'MIT ID': '923423691',
#   'Student Name': 'Summers, Fleur S.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'aliquet.libero.Integer@lectussit.net'},
#  {'MIT ID': '926982465',
#   'Student Name': 'Bailey, Sylvester F.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'vel@id.ca'},
#  {'MIT ID': '913342240',
#   'Student Name': 'Mcbride, Cassidy D.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ipsum.sodales@purusmauris.edu'},
#  {'MIT ID': '919880706',
#   'Student Name': 'Wolfe, Ulla I.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'ac@cubiliaCuraePhasellus.org'},
#  {'MIT ID': '926067641',
#   'Student Name': 'Vargas, Gannon Z.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Donec.dignissim@luctus.ca'},
#  {'MIT ID': '915755425',
#   'Student Name': 'Cross, Branden G.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'libero@sagittislobortismauris.net'},
#  {'MIT ID': '919431629',
#   'Student Name': 'Pittman, Randall H.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'sed@quamquisdiam.edu'},
#  {'MIT ID': '910953542',
#   'Student Name': 'Berry, Felix I.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'eu.arcu.Morbi@Curabituregestasnunc.co.uk'},
#  {'MIT ID': '924906378',
#   'Student Name': 'Valencia, Connor A.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Proin@vitae.net'},
#  {'MIT ID': '927208245',
#   'Student Name': 'Oneal, Eric U.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'magna.Sed.eu@loremlorem.ca'},
#  {'MIT ID': '923030771',
#   'Student Name': 'Moss, Aileen M.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Quisque@sitametnulla.co.uk'},
#  {'MIT ID': '924894683',
#   'Student Name': 'Acosta, Joy F.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'malesuada.vel.venenatis@egetmagnaSuspendisse.com'},
#  {'MIT ID': '922723034',
#   'Student Name': 'Hall, Kelsey J.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Nunc.laoreet@adlitora.net'},
#  {'MIT ID': '913243942',
#   'Student Name': 'Martin, Cameran E.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'magnis.dis@fringillapurus.org'},
#  {'MIT ID': '917058638',
#   'Student Name': 'Dejesus, Erich Z.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'quis@Suspendisse.net'},
#  {'MIT ID': '925541232',
#   'Student Name': 'Francis, Lawrence D.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Proin.nisl.sem@DonectinciduntDonec.com'},
#  {'MIT ID': '927836579',
#   'Student Name': 'Reeves, Dennis O.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'aliquet.metus.urna@interdum.edu'},
#  {'MIT ID': '912933890',
#   'Student Name': 'Wells, Kameko S.',
#   'Course': '6 3',
#   'Y': '2',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'sem.semper.erat@mattissemper.net'},
#  {'MIT ID': '914725703',
#   'Student Name': 'Combs, Barrett N.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'Fusce@risus.co.uk'},
#  {'MIT ID': '923737537',
#   'Student Name': 'Crane, Harding O.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'nonummy.Fusce.fermentum@luctussitamet.co.uk'},
#  {'MIT ID': '925871958',
#   'Student Name': 'Ward, Hall G.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'erat@auguemalesuada.net'},
#  {'MIT ID': '920539948',
#   'Student Name': 'Wise, Rebekah T.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'commodo.hendrerit.Donec@congueaaliquet.net'},
#  {'MIT ID': '920302528',
#   'Student Name': 'Herring, Aretha J.',
#   'Course': '6 3',
#   'Y': '1',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'et@turpisegestasAliquam.org'},
#  {'MIT ID': '916233532',
#   'Student Name': 'Bird, Dillon U.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'diam.Proin.dolor@pretiumnequeMorbi.ca'},
#  {'MIT ID': '926888914',
#   'Student Name': 'Cantu, Shellie R.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'adipiscing.elit@eutellusPhasellus.edu'},
#  {'MIT ID': '917002941',
#   'Student Name': 'Blake, Madeline H.',
#   'Course': '6 3',
#   'Y': '3',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'cursus.a@feugiattelluslorem.edu'},
#  {'MIT ID': '910866579',
#   'Student Name': 'Myers, Vernon X.',
#   'Course': '6 3',
#   'Y': '4',
#   'St': 'Reg',
#   'Un': '12',
#   'Grade': '',
#   'Enrolled': '6.666',
#   'Sec': '',
#   'Email Address': 'adipiscing@lobortisnisi.com'}]

# %% [markdown]
# # Parsing XML Grades Data
#
# Our next challenge is to read the class grades spreadsheet, which we're imagining is in [XML](https://en.wikipedia.org/wiki/XML), an extremely popular textual format for tree-structured data.  XML is so popular, in fact, that you can open XML files in Firefox or Chrome and get some basic help navigating the trees.  We generate random grades XML files for testing purposes, and we can view them in any text editor, as well as some web browsers.  See file `grades.xml`.
#
# We use some ad-hoc code for general XML parsing.  (Actually, we only handle a simple subset of XML, sufficient for this example.)  The algorithm is moderately straightforward, depending at each point on a *tag stack*.  XML documents represent trees, and, at any point in parsing, we are processing some *tag*, or tree node.  The stack at that point stores all the ancestors of the current tag, in order.  As we finish parsing a node, we add that node to the children list of its parent, and we need the stack to find that parent.
#
# First, let's build a simple generator to yield all characters in a text file that we've opened.

# %%
def characters(f):
    """For f an open file, yield all its characters in order."""
    
    while True:
        c = f.read(1)
        if not c:
            return
        yield c

# %%
def parseXml(filename):
    """Parse one XML tag (with children) from a file."""
    with open(filename, "r") as f:
        # We maintain a stack of tags that we are still working on.
        # Each is an object that contains a list of children.
        # We start with a dummy tag standing for the document root.
        stack = [{"tag": "root", "children": [], "text": ""}]

        # Now we loop until there is no more content to read.
        while True:
            # Step 1: Find the start of the open tag.
            for ch in characters(f):
                if ch == '<':
                    # Oo, an open tag!  Exit the loop and start processing the tag name.
                    break
                else:
                    # This character has no special interpretation.  Add it to the string for the parent tag.
                    stack[-1]["text"] += ch

            # Step 2: Extract the tag name.
            is_closer = False
            tag = ""
            for ch in characters(f):
                if ch == '/':
                    # Oh, a closing tag.  We'll need to pop from the stack afterward.
                    is_closer = True
                elif ch == '>':
                    # Found the end
                    break
                else:
                    # Found another character in the tag name.
                    tag += ch

            # Step 3: Manipulate the tag stack appropriately.
            if tag == "":
                # We seem to have reached the end of the file.
                break
            elif is_closer:
                # For a closing tag, pop it off, adding it to the children list of the top of the stack,
                # after removing leading and trailing spaces.
                this_node = stack.pop()
                this_node["text"] = trim(this_node["text"])
                stack[-1]["children"].append(this_node)
            else:
                # For an opening tag, add it to the stack.
                stack.append({"tag": tag, "children": [], "text": ""})

        # Now we should find the main tag as the sole child of the root node.
        return stack[0]["children"][0]

# %%
grades = parseXml("grades.xml")
grades
# Out:
# {'tag': 'grades',
#  'children': [{'tag': 'psets',
#    'children': [{'tag': 'pset',
#      'children': [{'tag': 'number', 'children': [], 'text': '1'},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci.quis@dignissim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '79'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'dui@enim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu@Craseget.com'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.vel@Vestibulum.org'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'at@massa.net'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'in@iaculis.org'},
#         {'tag': 'grade', 'children': [], 'text': '18'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'porttitor.eros@ametdapibus.com'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci.tincidunt.adipiscing@lobortisrisusIn.org'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Curabitur.egestas.nunc@erat.org'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ante.ipsum@Phasellusat.edu'},
#         {'tag': 'grade', 'children': [], 'text': '69'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'faucibus@elitNulla.edu'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.ullamcorper@aceleifend.net'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dolor.Quisque.tincidunt@quisarcuvel.com'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'turpis@milorem.ca'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'semper.auctor.Mauris@Maurismagna.com'},
#         {'tag': 'grade', 'children': [], 'text': '73'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'blandit@augue.ca'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'tellus.imperdiet@necmetus.net'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dui.quis@pretiumneque.com'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'tristique.aliquet.Phasellus@dictumeuplacerat.ca'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sit@duiSuspendisse.edu'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'pede.Nunc.sed@justoProin.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu.ultrices.sit@tempuseu.ca'},
#         {'tag': 'grade', 'children': [], 'text': '55'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Cras.pellentesque.Sed@ligulatortor.ca'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ut.nulla@Aliquam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '72'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.Nulla@lacuspedesagittis.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Integer.tincidunt.aliquam@enim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'convallis.convallis@facilisi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Etiam.laoreet.libero@amet.org'},
#         {'tag': 'grade', 'children': [], 'text': '76'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'pede@pharetrasedhendrerit.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'congue.a@eudoloregestas.edu'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'gravida.Aliquam.tincidunt@nulla.ca'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vitae@Pellentesque.com'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'inceptos@semperet.ca'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nec.cursus@arcuVestibulumante.net'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'mauris.Morbi@aliquetnec.edu'},
#         {'tag': 'grade', 'children': [], 'text': '11'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Donec.consectetuer.mauris@feugiat.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ultricies.sem.magna@scelerisquenequeNullam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nulla@atauctorullamcorper.com'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.laoreet@Aliquamrutrum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '66'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'a@acarcuNunc.org'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Phasellus.fermentum@Proin.org'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dui.in.sodales@lorem.org'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nisl.Maecenas@justo.com'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'volutpat@quis.com'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vitae.orci.Phasellus@turpis.com'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'odio@nonmassa.net'},
#         {'tag': 'grade', 'children': [], 'text': '49'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Phasellus.at.augue@eu.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '61'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vel@enimnonnisi.com'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci@purusDuiselementum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Pellentesque@eros.ca'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Mauris.non.dui@blanditatnisi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'Fusce@vitae.ca'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'malesuada.Integer@ornareplacerat.com'},
#         {'tag': 'grade', 'children': [], 'text': '25'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'id.ante@tellus.net'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.Nulla@at.edu'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ut.nulla.Cras@nisi.org'},
#         {'tag': 'grade', 'children': [], 'text': '77'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'enim.diam.vel@fringillamilacinia.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '84'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'et.commodo@elit.com'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nulla.Integer.urna@tortor.ca'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'velit.Quisque@scelerisque.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.sem@non.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'odio.Aliquam@rhoncus.ca'},
#         {'tag': 'grade', 'children': [], 'text': '81'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'non@Proinmi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'lorem.fringilla.ornare@non.com'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ante@auctorMauris.edu'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ullamcorper.Duis.at@netus.org'},
#         {'tag': 'grade', 'children': [], 'text': '66'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'non.massa.non@Morbivehicula.org'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Maecenas.mi@Etiamvestibulum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '14'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Quisque.porttitor.eros@enimMauris.ca'},
#         {'tag': 'grade', 'children': [], 'text': '76'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'consequat.purus.Maecenas@eratSed.com'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'mi@felis.edu'},
#         {'tag': 'grade', 'children': [], 'text': '53'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'orci@metus.edu'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.libero.Integer@lectussit.net'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'vel@id.ca'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ipsum.sodales@purusmauris.edu'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ac@cubiliaCuraePhasellus.org'},
#         {'tag': 'grade', 'children': [], 'text': '72'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Donec.dignissim@luctus.ca'},
#         {'tag': 'grade', 'children': [], 'text': '60'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'libero@sagittislobortismauris.net'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sed@quamquisdiam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu.arcu.Morbi@Curabituregestasnunc.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Proin@vitae.net'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'magna.Sed.eu@loremlorem.ca'},
#         {'tag': 'grade', 'children': [], 'text': '84'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Quisque@sitametnulla.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'malesuada.vel.venenatis@egetmagnaSuspendisse.com'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.laoreet@adlitora.net'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'magnis.dis@fringillapurus.org'},
#         {'tag': 'grade', 'children': [], 'text': '45'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'quis@Suspendisse.net'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Proin.nisl.sem@DonectinciduntDonec.com'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.metus.urna@interdum.edu'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.semper.erat@mattissemper.net'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Fusce@risus.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nonummy.Fusce.fermentum@luctussitamet.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'erat@auguemalesuada.net'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'commodo.hendrerit.Donec@congueaaliquet.net'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'et@turpisegestasAliquam.org'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'diam.Proin.dolor@pretiumnequeMorbi.ca'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'adipiscing.elit@eutellusPhasellus.edu'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'cursus.a@feugiattelluslorem.edu'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'adipiscing@lobortisnisi.com'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''}],
#      'text': ''},
#     {'tag': 'pset',
#      'children': [{'tag': 'number', 'children': [], 'text': '2'},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci.quis@dignissim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'dui@enim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '79'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu@Craseget.com'},
#         {'tag': 'grade', 'children': [], 'text': '64'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.vel@Vestibulum.org'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'at@massa.net'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'in@iaculis.org'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'porttitor.eros@ametdapibus.com'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci.tincidunt.adipiscing@lobortisrisusIn.org'},
#         {'tag': 'grade', 'children': [], 'text': '33'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Curabitur.egestas.nunc@erat.org'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ante.ipsum@Phasellusat.edu'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'faucibus@elitNulla.edu'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.ullamcorper@aceleifend.net'},
#         {'tag': 'grade', 'children': [], 'text': '77'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dolor.Quisque.tincidunt@quisarcuvel.com'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'turpis@milorem.ca'},
#         {'tag': 'grade', 'children': [], 'text': '81'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'semper.auctor.Mauris@Maurismagna.com'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'blandit@augue.ca'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'tellus.imperdiet@necmetus.net'},
#         {'tag': 'grade', 'children': [], 'text': '75'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dui.quis@pretiumneque.com'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'tristique.aliquet.Phasellus@dictumeuplacerat.ca'},
#         {'tag': 'grade', 'children': [], 'text': '62'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sit@duiSuspendisse.edu'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'pede.Nunc.sed@justoProin.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu.ultrices.sit@tempuseu.ca'},
#         {'tag': 'grade', 'children': [], 'text': '84'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Cras.pellentesque.Sed@ligulatortor.ca'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ut.nulla@Aliquam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.Nulla@lacuspedesagittis.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Integer.tincidunt.aliquam@enim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'convallis.convallis@facilisi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Etiam.laoreet.libero@amet.org'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'pede@pharetrasedhendrerit.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '81'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'congue.a@eudoloregestas.edu'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'gravida.Aliquam.tincidunt@nulla.ca'},
#         {'tag': 'grade', 'children': [], 'text': '78'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vitae@Pellentesque.com'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'inceptos@semperet.ca'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nec.cursus@arcuVestibulumante.net'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'mauris.Morbi@aliquetnec.edu'},
#         {'tag': 'grade', 'children': [], 'text': '57'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Donec.consectetuer.mauris@feugiat.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ultricies.sem.magna@scelerisquenequeNullam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nulla@atauctorullamcorper.com'},
#         {'tag': 'grade', 'children': [], 'text': '46'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.laoreet@Aliquamrutrum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'a@acarcuNunc.org'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Phasellus.fermentum@Proin.org'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dui.in.sodales@lorem.org'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nisl.Maecenas@justo.com'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'volutpat@quis.com'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vitae.orci.Phasellus@turpis.com'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'odio@nonmassa.net'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Phasellus.at.augue@eu.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vel@enimnonnisi.com'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci@purusDuiselementum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '75'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Pellentesque@eros.ca'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Mauris.non.dui@blanditatnisi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '73'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'Fusce@vitae.ca'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'malesuada.Integer@ornareplacerat.com'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'id.ante@tellus.net'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.Nulla@at.edu'},
#         {'tag': 'grade', 'children': [], 'text': '65'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ut.nulla.Cras@nisi.org'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'enim.diam.vel@fringillamilacinia.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '73'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'et.commodo@elit.com'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nulla.Integer.urna@tortor.ca'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'velit.Quisque@scelerisque.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '78'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.sem@non.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'odio.Aliquam@rhoncus.ca'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'non@Proinmi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'lorem.fringilla.ornare@non.com'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ante@auctorMauris.edu'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ullamcorper.Duis.at@netus.org'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'non.massa.non@Morbivehicula.org'},
#         {'tag': 'grade', 'children': [], 'text': '68'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Maecenas.mi@Etiamvestibulum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Quisque.porttitor.eros@enimMauris.ca'},
#         {'tag': 'grade', 'children': [], 'text': '84'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'consequat.purus.Maecenas@eratSed.com'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'mi@felis.edu'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'orci@metus.edu'},
#         {'tag': 'grade', 'children': [], 'text': '33'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.libero.Integer@lectussit.net'},
#         {'tag': 'grade', 'children': [], 'text': '6'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'vel@id.ca'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ipsum.sodales@purusmauris.edu'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ac@cubiliaCuraePhasellus.org'},
#         {'tag': 'grade', 'children': [], 'text': '45'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Donec.dignissim@luctus.ca'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'libero@sagittislobortismauris.net'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sed@quamquisdiam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu.arcu.Morbi@Curabituregestasnunc.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Proin@vitae.net'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'magna.Sed.eu@loremlorem.ca'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Quisque@sitametnulla.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'malesuada.vel.venenatis@egetmagnaSuspendisse.com'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.laoreet@adlitora.net'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'magnis.dis@fringillapurus.org'},
#         {'tag': 'grade', 'children': [], 'text': '75'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'quis@Suspendisse.net'},
#         {'tag': 'grade', 'children': [], 'text': '76'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Proin.nisl.sem@DonectinciduntDonec.com'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.metus.urna@interdum.edu'},
#         {'tag': 'grade', 'children': [], 'text': '81'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.semper.erat@mattissemper.net'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Fusce@risus.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nonummy.Fusce.fermentum@luctussitamet.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'erat@auguemalesuada.net'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'commodo.hendrerit.Donec@congueaaliquet.net'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'et@turpisegestasAliquam.org'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'diam.Proin.dolor@pretiumnequeMorbi.ca'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'adipiscing.elit@eutellusPhasellus.edu'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'cursus.a@feugiattelluslorem.edu'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'adipiscing@lobortisnisi.com'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''}],
#      'text': ''},
#     {'tag': 'pset',
#      'children': [{'tag': 'number', 'children': [], 'text': '3'},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '71'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci.quis@dignissim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'dui@enim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu@Craseget.com'},
#         {'tag': 'grade', 'children': [], 'text': '17'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.vel@Vestibulum.org'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'at@massa.net'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'in@iaculis.org'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'porttitor.eros@ametdapibus.com'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci.tincidunt.adipiscing@lobortisrisusIn.org'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Curabitur.egestas.nunc@erat.org'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ante.ipsum@Phasellusat.edu'},
#         {'tag': 'grade', 'children': [], 'text': '79'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'faucibus@elitNulla.edu'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.ullamcorper@aceleifend.net'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dolor.Quisque.tincidunt@quisarcuvel.com'},
#         {'tag': 'grade', 'children': [], 'text': '79'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'turpis@milorem.ca'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'semper.auctor.Mauris@Maurismagna.com'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'blandit@augue.ca'},
#         {'tag': 'grade', 'children': [], 'text': '71'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'tellus.imperdiet@necmetus.net'},
#         {'tag': 'grade', 'children': [], 'text': '93'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dui.quis@pretiumneque.com'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'tristique.aliquet.Phasellus@dictumeuplacerat.ca'},
#         {'tag': 'grade', 'children': [], 'text': '70'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sit@duiSuspendisse.edu'},
#         {'tag': 'grade', 'children': [], 'text': '88'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'pede.Nunc.sed@justoProin.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '72'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu.ultrices.sit@tempuseu.ca'},
#         {'tag': 'grade', 'children': [], 'text': '70'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Cras.pellentesque.Sed@ligulatortor.ca'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ut.nulla@Aliquam.edu'},
# ...
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.Nulla@lacuspedesagittis.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Integer.tincidunt.aliquam@enim.ca'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'convallis.convallis@facilisi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Etiam.laoreet.libero@amet.org'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'pede@pharetrasedhendrerit.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'congue.a@eudoloregestas.edu'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'gravida.Aliquam.tincidunt@nulla.ca'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vitae@Pellentesque.com'},
#         {'tag': 'grade', 'children': [], 'text': '74'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'inceptos@semperet.ca'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nec.cursus@arcuVestibulumante.net'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'mauris.Morbi@aliquetnec.edu'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Donec.consectetuer.mauris@feugiat.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ultricies.sem.magna@scelerisquenequeNullam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '78'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nulla@atauctorullamcorper.com'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.laoreet@Aliquamrutrum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '90'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'a@acarcuNunc.org'},
#         {'tag': 'grade', 'children': [], 'text': '63'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Phasellus.fermentum@Proin.org'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'dui.in.sodales@lorem.org'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nisl.Maecenas@justo.com'},
#         {'tag': 'grade', 'children': [], 'text': '84'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'volutpat@quis.com'},
#         {'tag': 'grade', 'children': [], 'text': '73'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vitae.orci.Phasellus@turpis.com'},
#         {'tag': 'grade', 'children': [], 'text': '75'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'odio@nonmassa.net'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Phasellus.at.augue@eu.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '78'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'vel@enimnonnisi.com'},
#         {'tag': 'grade', 'children': [], 'text': '61'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'orci@purusDuiselementum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '77'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Pellentesque@eros.ca'},
#         {'tag': 'grade', 'children': [], 'text': '76'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Mauris.non.dui@blanditatnisi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '100'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'Fusce@vitae.ca'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'malesuada.Integer@ornareplacerat.com'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'id.ante@tellus.net'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.Nulla@at.edu'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ut.nulla.Cras@nisi.org'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'enim.diam.vel@fringillamilacinia.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'et.commodo@elit.com'},
#         {'tag': 'grade', 'children': [], 'text': '65'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nulla.Integer.urna@tortor.ca'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'velit.Quisque@scelerisque.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.sem@non.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'odio.Aliquam@rhoncus.ca'},
#         {'tag': 'grade', 'children': [], 'text': '71'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'non@Proinmi.edu'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'lorem.fringilla.ornare@non.com'},
#         {'tag': 'grade', 'children': [], 'text': '89'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ante@auctorMauris.edu'},
#         {'tag': 'grade', 'children': [], 'text': '63'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ullamcorper.Duis.at@netus.org'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'non.massa.non@Morbivehicula.org'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Maecenas.mi@Etiamvestibulum.ca'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Quisque.porttitor.eros@enimMauris.ca'},
#         {'tag': 'grade', 'children': [], 'text': '86'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'consequat.purus.Maecenas@eratSed.com'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'mi@felis.edu'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'orci@metus.edu'},
#         {'tag': 'grade', 'children': [], 'text': '49'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.libero.Integer@lectussit.net'},
#         {'tag': 'grade', 'children': [], 'text': '85'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email', 'children': [], 'text': 'vel@id.ca'},
#         {'tag': 'grade', 'children': [], 'text': '95'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ipsum.sodales@purusmauris.edu'},
#         {'tag': 'grade', 'children': [], 'text': '36'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'ac@cubiliaCuraePhasellus.org'},
#         {'tag': 'grade', 'children': [], 'text': '98'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Donec.dignissim@luctus.ca'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'libero@sagittislobortismauris.net'},
#         {'tag': 'grade', 'children': [], 'text': '94'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sed@quamquisdiam.edu'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'eu.arcu.Morbi@Curabituregestasnunc.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Proin@vitae.net'},
#         {'tag': 'grade', 'children': [], 'text': '72'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'magna.Sed.eu@loremlorem.ca'},
#         {'tag': 'grade', 'children': [], 'text': '92'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Quisque@sitametnulla.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '82'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'malesuada.vel.venenatis@egetmagnaSuspendisse.com'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Nunc.laoreet@adlitora.net'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'magnis.dis@fringillapurus.org'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'quis@Suspendisse.net'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Proin.nisl.sem@DonectinciduntDonec.com'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'aliquet.metus.urna@interdum.edu'},
#         {'tag': 'grade', 'children': [], 'text': '80'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'sem.semper.erat@mattissemper.net'},
#         {'tag': 'grade', 'children': [], 'text': '87'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'Fusce@risus.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'nonummy.Fusce.fermentum@luctussitamet.co.uk'},
#         {'tag': 'grade', 'children': [], 'text': '83'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'erat@auguemalesuada.net'},
#         {'tag': 'grade', 'children': [], 'text': '91'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'commodo.hendrerit.Donec@congueaaliquet.net'},
#         {'tag': 'grade', 'children': [], 'text': '6'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'et@turpisegestasAliquam.org'},
#         {'tag': 'grade', 'children': [], 'text': '71'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'diam.Proin.dolor@pretiumnequeMorbi.ca'},
#         {'tag': 'grade', 'children': [], 'text': '99'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'adipiscing.elit@eutellusPhasellus.edu'},
#         {'tag': 'grade', 'children': [], 'text': '96'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'cursus.a@feugiattelluslorem.edu'},
#         {'tag': 'grade', 'children': [], 'text': '76'}],
#        'text': ''},
#       {'tag': 'student',
#        'children': [{'tag': 'email',
#          'children': [],
#          'text': 'adipiscing@lobortisnisi.com'},
#         {'tag': 'grade', 'children': [], 'text': '97'}],
#        'text': ''}],
#      'text': ''}],
#    'text': ''}],
#  'text': ''}

# %% [markdown]
# We postprocess the XML to generate more natural Python data structures, for instance using dictionaries in place of lists of child tags.

# %%
def assignmentFromXml(xml):
    """Convert one assignment (pset or quiz) to a nicer format."""
    
    number = [int(child["text"])
              for child in xml["children"]
              if child["tag"] == "number"][0]

    students = {email["text"]: int(grade["text"])
                for child in xml["children"]
                if child["tag"] == "student"
                for email in child["children"]
                if email["tag"] == "email"
                for grade in child["children"]
                if grade["tag"] == "grade"}

    return {"number": number, "students": students}

def categoryFromXml(xml, singular):
    """Convert one category (psets or quizzes) to a nicer format."""
    
    return {item["number"]: item["students"]
            for child in xml["children"]
            if child["tag"] == singular
            for item in [assignmentFromXml(child)]}

def gradesFromXml(xml):
    """Convert a whole grades database from XML to a nicer format."""
    
    psets = [child
             for child in xml["children"]
             if child["tag"] == "psets"][0]
    quizzes = [child
               for child in xml["children"]
               if child["tag"] == "quizzes"][0]

    return {"psets": categoryFromXml(psets, "pset"),
            "quizzes": categoryFromXml(quizzes, "quiz")}

# %% [markdown]
# Bringing it all together:

# %%
def parseGrades(filename):
    """Return the nice version of the grades database found in the file."""
    
    return gradesFromXml(parseXml(filename))

# %%
grades = parseGrades("grades.xml")
grades
# Out:
# {'psets': {1: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 100,
#    'orci.quis@dignissim.ca': 79,
#    'dui@enim.ca': 96,
#    'eu@Craseget.com': 82,
#    'aliquet.vel@Vestibulum.org': 94,
#    'at@massa.net': 87,
#    'in@iaculis.org': 18,
#    'porttitor.eros@ametdapibus.com': 100,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 85,
#    'Curabitur.egestas.nunc@erat.org': 97,
#    'ante.ipsum@Phasellusat.edu': 69,
#    'faucibus@elitNulla.edu': 80,
#    'Nunc.ullamcorper@aceleifend.net': 87,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 86,
#    'turpis@milorem.ca': 99,
#    'semper.auctor.Mauris@Maurismagna.com': 73,
#    'blandit@augue.ca': 93,
#    'tellus.imperdiet@necmetus.net': 82,
#    'dui.quis@pretiumneque.com': 97,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 94,
#    'sit@duiSuspendisse.edu': 88,
#    'pede.Nunc.sed@justoProin.co.uk': 93,
#    'eu.ultrices.sit@tempuseu.ca': 55,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 85,
#    'ut.nulla@Aliquam.edu': 72,
#    'sem.Nulla@lacuspedesagittis.co.uk': 83,
#    'Integer.tincidunt.aliquam@enim.ca': 98,
#    'convallis.convallis@facilisi.edu': 86,
#    'Etiam.laoreet.libero@amet.org': 76,
#    'pede@pharetrasedhendrerit.co.uk': 92,
#    'congue.a@eudoloregestas.edu': 94,
#    'gravida.Aliquam.tincidunt@nulla.ca': 92,
#    'vitae@Pellentesque.com': 100,
#    'inceptos@semperet.ca': 100,
#    'nec.cursus@arcuVestibulumante.net': 94,
#    'mauris.Morbi@aliquetnec.edu': 11,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 99,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 93,
#    'Nulla@atauctorullamcorper.com': 93,
#    'Nunc.laoreet@Aliquamrutrum.ca': 66,
#    'a@acarcuNunc.org': 90,
#    'Phasellus.fermentum@Proin.org': 95,
#    'dui.in.sodales@lorem.org': 98,
#    'nisl.Maecenas@justo.com': 97,
#    'volutpat@quis.com': 96,
#    'vitae.orci.Phasellus@turpis.com': 93,
#    'odio@nonmassa.net': 49,
#    'Phasellus.at.augue@eu.co.uk': 61,
#    'vel@enimnonnisi.com': 97,
#    'orci@purusDuiselementum.ca': 93,
#    'Pellentesque@eros.ca': 99,
#    'Mauris.non.dui@blanditatnisi.edu': 91,
#    'Fusce@vitae.ca': 95,
#    'malesuada.Integer@ornareplacerat.com': 25,
#    'id.ante@tellus.net': 96,
#    'sem.Nulla@at.edu': 96,
#    'ut.nulla.Cras@nisi.org': 77,
#    'enim.diam.vel@fringillamilacinia.co.uk': 84,
#    'et.commodo@elit.com': 95,
#    'nulla.Integer.urna@tortor.ca': 99,
#    'velit.Quisque@scelerisque.co.uk': 87,
#    'aliquet.sem@non.co.uk': 94,
#    'odio.Aliquam@rhoncus.ca': 81,
#    'non@Proinmi.edu': 89,
#    'lorem.fringilla.ornare@non.com': 94,
#    'ante@auctorMauris.edu': 94,
#    'ullamcorper.Duis.at@netus.org': 66,
#    'non.massa.non@Morbivehicula.org': 94,
#    'Maecenas.mi@Etiamvestibulum.ca': 14,
#    'Quisque.porttitor.eros@enimMauris.ca': 76,
#    'consequat.purus.Maecenas@eratSed.com': 93,
#    'mi@felis.edu': 53,
#    'orci@metus.edu': 97,
#    'aliquet.libero.Integer@lectussit.net': 86,
#    'vel@id.ca': 99,
#    'ipsum.sodales@purusmauris.edu': 100,
#    'ac@cubiliaCuraePhasellus.org': 72,
#    'Donec.dignissim@luctus.ca': 60,
#    'libero@sagittislobortismauris.net': 98,
#    'sed@quamquisdiam.edu': 91,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 82,
#    'Proin@vitae.net': 82,
#    'magna.Sed.eu@loremlorem.ca': 84,
#    'Quisque@sitametnulla.co.uk': 90,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 94,
#    'Nunc.laoreet@adlitora.net': 86,
#    'magnis.dis@fringillapurus.org': 45,
#    'quis@Suspendisse.net': 80,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 100,
#    'aliquet.metus.urna@interdum.edu': 95,
#    'sem.semper.erat@mattissemper.net': 98,
#    'Fusce@risus.co.uk': 99,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 89,
#    'erat@auguemalesuada.net': 80,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 97,
#    'et@turpisegestasAliquam.org': 88,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 96,
#    'adipiscing.elit@eutellusPhasellus.edu': 91,
#    'cursus.a@feugiattelluslorem.edu': 89,
#    'adipiscing@lobortisnisi.com': 98},
#   2: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 95,
#    'orci.quis@dignissim.ca': 85,
#    'dui@enim.ca': 79,
#    'eu@Craseget.com': 64,
#    'aliquet.vel@Vestibulum.org': 91,
#    'at@massa.net': 98,
#    'in@iaculis.org': 95,
#    'porttitor.eros@ametdapibus.com': 85,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 33,
#    'Curabitur.egestas.nunc@erat.org': 100,
#    'ante.ipsum@Phasellusat.edu': 93,
#    'faucibus@elitNulla.edu': 89,
#    'Nunc.ullamcorper@aceleifend.net': 77,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 92,
#    'turpis@milorem.ca': 81,
#    'semper.auctor.Mauris@Maurismagna.com': 92,
#    'blandit@augue.ca': 97,
#    'tellus.imperdiet@necmetus.net': 75,
#    'dui.quis@pretiumneque.com': 97,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 62,
#    'sit@duiSuspendisse.edu': 97,
#    'pede.Nunc.sed@justoProin.co.uk': 88,
#    'eu.ultrices.sit@tempuseu.ca': 84,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 83,
#    'ut.nulla@Aliquam.edu': 95,
#    'sem.Nulla@lacuspedesagittis.co.uk': 85,
#    'Integer.tincidunt.aliquam@enim.ca': 82,
#    'convallis.convallis@facilisi.edu': 93,
#    'Etiam.laoreet.libero@amet.org': 100,
#    'pede@pharetrasedhendrerit.co.uk': 81,
#    'congue.a@eudoloregestas.edu': 88,
#    'gravida.Aliquam.tincidunt@nulla.ca': 78,
#    'vitae@Pellentesque.com': 95,
#    'inceptos@semperet.ca': 91,
#    'nec.cursus@arcuVestibulumante.net': 100,
#    'mauris.Morbi@aliquetnec.edu': 57,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 86,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 99,
#    'Nulla@atauctorullamcorper.com': 46,
#    'Nunc.laoreet@Aliquamrutrum.ca': 91,
#    'a@acarcuNunc.org': 88,
#    'Phasellus.fermentum@Proin.org': 90,
#    'dui.in.sodales@lorem.org': 91,
#    'nisl.Maecenas@justo.com': 91,
#    'volutpat@quis.com': 95,
#    'vitae.orci.Phasellus@turpis.com': 96,
#    'odio@nonmassa.net': 100,
#    'Phasellus.at.augue@eu.co.uk': 93,
#    'vel@enimnonnisi.com': 80,
#    'orci@purusDuiselementum.ca': 75,
#    'Pellentesque@eros.ca': 92,
#    'Mauris.non.dui@blanditatnisi.edu': 73,
#    'Fusce@vitae.ca': 96,
#    'malesuada.Integer@ornareplacerat.com': 94,
#    'id.ante@tellus.net': 90,
#    'sem.Nulla@at.edu': 65,
#    'ut.nulla.Cras@nisi.org': 83,
#    'enim.diam.vel@fringillamilacinia.co.uk': 73,
#    'et.commodo@elit.com': 100,
#    'nulla.Integer.urna@tortor.ca': 88,
#    'velit.Quisque@scelerisque.co.uk': 78,
#    'aliquet.sem@non.co.uk': 96,
#    'odio.Aliquam@rhoncus.ca': 82,
#    'non@Proinmi.edu': 80,
#    'lorem.fringilla.ornare@non.com': 88,
#    'ante@auctorMauris.edu': 98,
#    'ullamcorper.Duis.at@netus.org': 91,
#    'non.massa.non@Morbivehicula.org': 68,
#    'Maecenas.mi@Etiamvestibulum.ca': 91,
#    'Quisque.porttitor.eros@enimMauris.ca': 84,
#    'consequat.purus.Maecenas@eratSed.com': 91,
#    'mi@felis.edu': 97,
#    'orci@metus.edu': 33,
#    'aliquet.libero.Integer@lectussit.net': 6,
#    'vel@id.ca': 95,
#    'ipsum.sodales@purusmauris.edu': 93,
#    'ac@cubiliaCuraePhasellus.org': 45,
#    'Donec.dignissim@luctus.ca': 96,
#    'libero@sagittislobortismauris.net': 80,
#    'sed@quamquisdiam.edu': 99,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 98,
#    'Proin@vitae.net': 87,
#    'magna.Sed.eu@loremlorem.ca': 95,
#    'Quisque@sitametnulla.co.uk': 87,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 87,
#    'Nunc.laoreet@adlitora.net': 92,
#    'magnis.dis@fringillapurus.org': 75,
#    'quis@Suspendisse.net': 76,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 96,
#    'aliquet.metus.urna@interdum.edu': 81,
#    'sem.semper.erat@mattissemper.net': 90,
#    'Fusce@risus.co.uk': 99,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 97,
#    'erat@auguemalesuada.net': 100,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 98,
#    'et@turpisegestasAliquam.org': 82,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 97,
#    'adipiscing.elit@eutellusPhasellus.edu': 95,
#    'cursus.a@feugiattelluslorem.edu': 95,
#    'adipiscing@lobortisnisi.com': 90},
#   3: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 71,
#    'orci.quis@dignissim.ca': 97,
#    'dui@enim.ca': 95,
#    'eu@Craseget.com': 17,
#    'aliquet.vel@Vestibulum.org': 88,
#    'at@massa.net': 93,
#    'in@iaculis.org': 97,
#    'porttitor.eros@ametdapibus.com': 90,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 89,
#    'Curabitur.egestas.nunc@erat.org': 96,
#    'ante.ipsum@Phasellusat.edu': 79,
#    'faucibus@elitNulla.edu': 96,
#    'Nunc.ullamcorper@aceleifend.net': 94,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 79,
#    'turpis@milorem.ca': 97,
#    'semper.auctor.Mauris@Maurismagna.com': 85,
#    'blandit@augue.ca': 71,
#    'tellus.imperdiet@necmetus.net': 93,
#    'dui.quis@pretiumneque.com': 89,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 70,
#    'sit@duiSuspendisse.edu': 88,
#    'pede.Nunc.sed@justoProin.co.uk': 72,
#    'eu.ultrices.sit@tempuseu.ca': 70,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 97,
#    'ut.nulla@Aliquam.edu': 51,
#    'sem.Nulla@lacuspedesagittis.co.uk': 92,
#    'Integer.tincidunt.aliquam@enim.ca': 95,
#    'convallis.convallis@facilisi.edu': 19,
#    'Etiam.laoreet.libero@amet.org': 91,
#    'pede@pharetrasedhendrerit.co.uk': 98,
#    'congue.a@eudoloregestas.edu': 99,
#    'gravida.Aliquam.tincidunt@nulla.ca': 97,
#    'vitae@Pellentesque.com': 99,
#    'inceptos@semperet.ca': 85,
#    'nec.cursus@arcuVestibulumante.net': 92,
#    'mauris.Morbi@aliquetnec.edu': 90,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 90,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 89,
#    'Nulla@atauctorullamcorper.com': 18,
#    'Nunc.laoreet@Aliquamrutrum.ca': 66,
#    'a@acarcuNunc.org': 60,
#    'Phasellus.fermentum@Proin.org': 100,
#    'dui.in.sodales@lorem.org': 77,
#    'nisl.Maecenas@justo.com': 76,
#    'volutpat@quis.com': 99,
#    'vitae.orci.Phasellus@turpis.com': 63,
#    'odio@nonmassa.net': 92,
#    'Phasellus.at.augue@eu.co.uk': 63,
#    'vel@enimnonnisi.com': 89,
#    'orci@purusDuiselementum.ca': 84,
#    'Pellentesque@eros.ca': 97,
#    'Mauris.non.dui@blanditatnisi.edu': 96,
#    'Fusce@vitae.ca': 23,
#    'malesuada.Integer@ornareplacerat.com': 90,
#    'id.ante@tellus.net': 84,
#    'sem.Nulla@at.edu': 94,
#    'ut.nulla.Cras@nisi.org': 97,
#    'enim.diam.vel@fringillamilacinia.co.uk': 87,
#    'et.commodo@elit.com': 92,
#    'nulla.Integer.urna@tortor.ca': 95,
#    'velit.Quisque@scelerisque.co.uk': 67,
#    'aliquet.sem@non.co.uk': 91,
#    'odio.Aliquam@rhoncus.ca': 93,
#    'non@Proinmi.edu': 84,
#    'lorem.fringilla.ornare@non.com': 100,
#    'ante@auctorMauris.edu': 82,
#    'ullamcorper.Duis.at@netus.org': 92,
#    'non.massa.non@Morbivehicula.org': 96,
#    'Maecenas.mi@Etiamvestibulum.ca': 91,
#    'Quisque.porttitor.eros@enimMauris.ca': 28,
#    'consequat.purus.Maecenas@eratSed.com': 91,
#    'mi@felis.edu': 84,
#    'orci@metus.edu': 98,
#    'aliquet.libero.Integer@lectussit.net': 100,
#    'vel@id.ca': 82,
#    'ipsum.sodales@purusmauris.edu': 92,
#    'ac@cubiliaCuraePhasellus.org': 90,
#    'Donec.dignissim@luctus.ca': 63,
#    'libero@sagittislobortismauris.net': 43,
#    'sed@quamquisdiam.edu': 83,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 98,
#    'Proin@vitae.net': 95,
#    'magna.Sed.eu@loremlorem.ca': 78,
#    'Quisque@sitametnulla.co.uk': 37,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 86,
#    'Nunc.laoreet@adlitora.net': 66,
#    'magnis.dis@fringillapurus.org': 68,
#    'quis@Suspendisse.net': 92,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 99,
#    'aliquet.metus.urna@interdum.edu': 91,
#    'sem.semper.erat@mattissemper.net': 97,
#    'Fusce@risus.co.uk': 90,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 38,
#    'erat@auguemalesuada.net': 99,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 92,
#    'et@turpisegestasAliquam.org': 98,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 74,
#    'adipiscing.elit@eutellusPhasellus.edu': 97,
#    'cursus.a@feugiattelluslorem.edu': 87,
#    'adipiscing@lobortisnisi.com': 93},
#   4: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 91,
#    'orci.quis@dignissim.ca': 89,
#    'dui@enim.ca': 92,
#    'eu@Craseget.com': 93,
#    'aliquet.vel@Vestibulum.org': 83,
#    'at@massa.net': 89,
#    'in@iaculis.org': 90,
#    'porttitor.eros@ametdapibus.com': 99,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 73,
#    'Curabitur.egestas.nunc@erat.org': 90,
#    'ante.ipsum@Phasellusat.edu': 65,
#    'faucibus@elitNulla.edu': 91,
#    'Nunc.ullamcorper@aceleifend.net': 90,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 98,
#    'turpis@milorem.ca': 90,
#    'semper.auctor.Mauris@Maurismagna.com': 95,
#    'blandit@augue.ca': 93,
#    'tellus.imperdiet@necmetus.net': 95,
#    'dui.quis@pretiumneque.com': 73,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 81,
#    'sit@duiSuspendisse.edu': 88,
#    'pede.Nunc.sed@justoProin.co.uk': 90,
#    'eu.ultrices.sit@tempuseu.ca': 90,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 95,
#    'ut.nulla@Aliquam.edu': 100,
#    'sem.Nulla@lacuspedesagittis.co.uk': 87,
#    'Integer.tincidunt.aliquam@enim.ca': 86,
#    'convallis.convallis@facilisi.edu': 70,
#    'Etiam.laoreet.libero@amet.org': 91,
#    'pede@pharetrasedhendrerit.co.uk': 87,
#    'congue.a@eudoloregestas.edu': 98,
#    'gravida.Aliquam.tincidunt@nulla.ca': 85,
#    'vitae@Pellentesque.com': 87,
#    'inceptos@semperet.ca': 90,
#    'nec.cursus@arcuVestibulumante.net': 70,
#    'mauris.Morbi@aliquetnec.edu': 94,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 85,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 78,
#    'Nulla@atauctorullamcorper.com': 88,
#    'Nunc.laoreet@Aliquamrutrum.ca': 81,
#    'a@acarcuNunc.org': 84,
#    'Phasellus.fermentum@Proin.org': 85,
#    'dui.in.sodales@lorem.org': 69,
#    'nisl.Maecenas@justo.com': 94,
#    'volutpat@quis.com': 92,
#    'vitae.orci.Phasellus@turpis.com': 70,
#    'odio@nonmassa.net': 91,
#    'Phasellus.at.augue@eu.co.uk': 23,
#    'vel@enimnonnisi.com': 78,
#    'orci@purusDuiselementum.ca': 97,
#    'Pellentesque@eros.ca': 95,
#    'Mauris.non.dui@blanditatnisi.edu': 35,
#    'Fusce@vitae.ca': 82,
#    'malesuada.Integer@ornareplacerat.com': 98,
#    'id.ante@tellus.net': 73,
#    'sem.Nulla@at.edu': 76,
#    'ut.nulla.Cras@nisi.org': 92,
#    'enim.diam.vel@fringillamilacinia.co.uk': 88,
#    'et.commodo@elit.com': 88,
#    'nulla.Integer.urna@tortor.ca': 87,
#    'velit.Quisque@scelerisque.co.uk': 92,
#    'aliquet.sem@non.co.uk': 87,
#    'odio.Aliquam@rhoncus.ca': 92,
#    'non@Proinmi.edu': 80,
#    'lorem.fringilla.ornare@non.com': 69,
#    'ante@auctorMauris.edu': 89,
#    'ullamcorper.Duis.at@netus.org': 86,
#    'non.massa.non@Morbivehicula.org': 98,
#    'Maecenas.mi@Etiamvestibulum.ca': 93,
#    'Quisque.porttitor.eros@enimMauris.ca': 99,
#    'consequat.purus.Maecenas@eratSed.com': 99,
#    'mi@felis.edu': 87,
#    'orci@metus.edu': 9,
#    'aliquet.libero.Integer@lectussit.net': 61,
#    'vel@id.ca': 91,
#    'ipsum.sodales@purusmauris.edu': 87,
#    'ac@cubiliaCuraePhasellus.org': 87,
#    'Donec.dignissim@luctus.ca': 82,
#    'libero@sagittislobortismauris.net': 99,
#    'sed@quamquisdiam.edu': 22,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 99,
#    'Proin@vitae.net': 95,
#    'magna.Sed.eu@loremlorem.ca': 86,
#    'Quisque@sitametnulla.co.uk': 79,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 29,
#    'Nunc.laoreet@adlitora.net': 95,
#    'magnis.dis@fringillapurus.org': 81,
#    'quis@Suspendisse.net': 100,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 5,
#    'aliquet.metus.urna@interdum.edu': 42,
#    'sem.semper.erat@mattissemper.net': 89,
#    'Fusce@risus.co.uk': 97,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 80,
#    'erat@auguemalesuada.net': 96,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 97,
#    'et@turpisegestasAliquam.org': 100,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 98,
#    'adipiscing.elit@eutellusPhasellus.edu': 98,
#    'cursus.a@feugiattelluslorem.edu': 62,
#    'adipiscing@lobortisnisi.com': 94},
#   5: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 87,
#    'orci.quis@dignissim.ca': 74,
#    'dui@enim.ca': 5,
#    'eu@Craseget.com': 85,
#    'aliquet.vel@Vestibulum.org': 26,
#    'at@massa.net': 90,
#    'in@iaculis.org': 87,
#    'porttitor.eros@ametdapibus.com': 74,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 89,
#    'Curabitur.egestas.nunc@erat.org': 94,
#    'ante.ipsum@Phasellusat.edu': 100,
#    'faucibus@elitNulla.edu': 73,
#    'Nunc.ullamcorper@aceleifend.net': 99,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 86,
#    'turpis@milorem.ca': 92,
#    'semper.auctor.Mauris@Maurismagna.com': 82,
#    'blandit@augue.ca': 77,
#    'tellus.imperdiet@necmetus.net': 87,
#    'dui.quis@pretiumneque.com': 82,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 76,
#    'sit@duiSuspendisse.edu': 90,
#    'pede.Nunc.sed@justoProin.co.uk': 69,
#    'eu.ultrices.sit@tempuseu.ca': 56,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 89,
#    'ut.nulla@Aliquam.edu': 64,
#    'sem.Nulla@lacuspedesagittis.co.uk': 91,
#    'Integer.tincidunt.aliquam@enim.ca': 98,
#    'convallis.convallis@facilisi.edu': 83,
#    'Etiam.laoreet.libero@amet.org': 82,
#    'pede@pharetrasedhendrerit.co.uk': 98,
#    'congue.a@eudoloregestas.edu': 98,
#    'gravida.Aliquam.tincidunt@nulla.ca': 91,
#    'vitae@Pellentesque.com': 97,
#    'inceptos@semperet.ca': 93,
#    'nec.cursus@arcuVestibulumante.net': 95,
#    'mauris.Morbi@aliquetnec.edu': 47,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 99,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 89,
#    'Nulla@atauctorullamcorper.com': 86,
#    'Nunc.laoreet@Aliquamrutrum.ca': 81,
#    'a@acarcuNunc.org': 86,
#    'Phasellus.fermentum@Proin.org': 64,
#    'dui.in.sodales@lorem.org': 98,
#    'nisl.Maecenas@justo.com': 82,
#    'volutpat@quis.com': 82,
#    'vitae.orci.Phasellus@turpis.com': 5,
#    'odio@nonmassa.net': 96,
#    'Phasellus.at.augue@eu.co.uk': 90,
#    'vel@enimnonnisi.com': 84,
#    'orci@purusDuiselementum.ca': 97,
#    'Pellentesque@eros.ca': 98,
#    'Mauris.non.dui@blanditatnisi.edu': 97,
#    'Fusce@vitae.ca': 85,
#    'malesuada.Integer@ornareplacerat.com': 99,
#    'id.ante@tellus.net': 95,
#    'sem.Nulla@at.edu': 64,
#    'ut.nulla.Cras@nisi.org': 96,
#    'enim.diam.vel@fringillamilacinia.co.uk': 91,
#    'et.commodo@elit.com': 90,
#    'nulla.Integer.urna@tortor.ca': 5,
#    'velit.Quisque@scelerisque.co.uk': 89,
#    'aliquet.sem@non.co.uk': 92,
#    'odio.Aliquam@rhoncus.ca': 98,
#    'non@Proinmi.edu': 100,
#    'lorem.fringilla.ornare@non.com': 86,
#    'ante@auctorMauris.edu': 26,
#    'ullamcorper.Duis.at@netus.org': 87,
#    'non.massa.non@Morbivehicula.org': 92,
#    'Maecenas.mi@Etiamvestibulum.ca': 63,
#    'Quisque.porttitor.eros@enimMauris.ca': 96,
#    'consequat.purus.Maecenas@eratSed.com': 80,
#    'mi@felis.edu': 97,
#    'orci@metus.edu': 71,
#    'aliquet.libero.Integer@lectussit.net': 81,
#    'vel@id.ca': 72,
#    'ipsum.sodales@purusmauris.edu': 62,
#    'ac@cubiliaCuraePhasellus.org': 95,
#    'Donec.dignissim@luctus.ca': 82,
#    'libero@sagittislobortismauris.net': 99,
#    'sed@quamquisdiam.edu': 91,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 95,
#    'Proin@vitae.net': 99,
#    'magna.Sed.eu@loremlorem.ca': 91,
#    'Quisque@sitametnulla.co.uk': 92,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 75,
#    'Nunc.laoreet@adlitora.net': 96,
#    'magnis.dis@fringillapurus.org': 96,
#    'quis@Suspendisse.net': 80,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 90,
#    'aliquet.metus.urna@interdum.edu': 96,
#    'sem.semper.erat@mattissemper.net': 80,
#    'Fusce@risus.co.uk': 89,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 94,
#    'erat@auguemalesuada.net': 91,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 93,
#    'et@turpisegestasAliquam.org': 82,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 91,
#    'adipiscing.elit@eutellusPhasellus.edu': 99,
#    'cursus.a@feugiattelluslorem.edu': 99,
#    'adipiscing@lobortisnisi.com': 85},
#   6: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 83,
#    'orci.quis@dignissim.ca': 96,
#    'dui@enim.ca': 81,
#    'eu@Craseget.com': 99,
#    'aliquet.vel@Vestibulum.org': 80,
#    'at@massa.net': 70,
#    'in@iaculis.org': 94,
#    'porttitor.eros@ametdapibus.com': 64,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 92,
#    'Curabitur.egestas.nunc@erat.org': 92,
#    'ante.ipsum@Phasellusat.edu': 95,
#    'faucibus@elitNulla.edu': 92,
#    'Nunc.ullamcorper@aceleifend.net': 98,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 75,
#    'turpis@milorem.ca': 63,
#    'semper.auctor.Mauris@Maurismagna.com': 93,
#    'blandit@augue.ca': 78,
#    'tellus.imperdiet@necmetus.net': 95,
#    'dui.quis@pretiumneque.com': 74,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 95,
#    'sit@duiSuspendisse.edu': 68,
#    'pede.Nunc.sed@justoProin.co.uk': 98,
#    'eu.ultrices.sit@tempuseu.ca': 59,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 92,
#    'ut.nulla@Aliquam.edu': 94,
#    'sem.Nulla@lacuspedesagittis.co.uk': 88,
#    'Integer.tincidunt.aliquam@enim.ca': 84,
#    'convallis.convallis@facilisi.edu': 96,
#    'Etiam.laoreet.libero@amet.org': 100,
#    'pede@pharetrasedhendrerit.co.uk': 95,
#    'congue.a@eudoloregestas.edu': 83,
#    'gravida.Aliquam.tincidunt@nulla.ca': 88,
#    'vitae@Pellentesque.com': 95,
#    'inceptos@semperet.ca': 82,
#    'nec.cursus@arcuVestibulumante.net': 72,
#    'mauris.Morbi@aliquetnec.edu': 97,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 90,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 90,
#    'Nulla@atauctorullamcorper.com': 92,
#    'Nunc.laoreet@Aliquamrutrum.ca': 62,
#    'a@acarcuNunc.org': 89,
#    'Phasellus.fermentum@Proin.org': 60,
#    'dui.in.sodales@lorem.org': 89,
#    'nisl.Maecenas@justo.com': 89,
#    'volutpat@quis.com': 90,
#    'vitae.orci.Phasellus@turpis.com': 98,
#    'odio@nonmassa.net': 98,
#    'Phasellus.at.augue@eu.co.uk': 90,
#    'vel@enimnonnisi.com': 91,
#    'orci@purusDuiselementum.ca': 98,
#    'Pellentesque@eros.ca': 89,
#    'Mauris.non.dui@blanditatnisi.edu': 100,
#    'Fusce@vitae.ca': 100,
#    'malesuada.Integer@ornareplacerat.com': 72,
#    'id.ante@tellus.net': 95,
#    'sem.Nulla@at.edu': 96,
#    'ut.nulla.Cras@nisi.org': 98,
#    'enim.diam.vel@fringillamilacinia.co.uk': 70,
#    'et.commodo@elit.com': 99,
#    'nulla.Integer.urna@tortor.ca': 90,
#    'velit.Quisque@scelerisque.co.uk': 72,
#    'aliquet.sem@non.co.uk': 60,
#    'odio.Aliquam@rhoncus.ca': 99,
#    'non@Proinmi.edu': 90,
#    'lorem.fringilla.ornare@non.com': 84,
#    'ante@auctorMauris.edu': 81,
#    'ullamcorper.Duis.at@netus.org': 96,
#    'non.massa.non@Morbivehicula.org': 97,
#    'Maecenas.mi@Etiamvestibulum.ca': 86,
#    'Quisque.porttitor.eros@enimMauris.ca': 93,
#    'consequat.purus.Maecenas@eratSed.com': 95,
#    'mi@felis.edu': 98,
#    'orci@metus.edu': 94,
#    'aliquet.libero.Integer@lectussit.net': 90,
#    'vel@id.ca': 100,
#    'ipsum.sodales@purusmauris.edu': 70,
#    'ac@cubiliaCuraePhasellus.org': 76,
#    'Donec.dignissim@luctus.ca': 87,
#    'libero@sagittislobortismauris.net': 92,
#    'sed@quamquisdiam.edu': 92,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 92,
#    'Proin@vitae.net': 100,
#    'magna.Sed.eu@loremlorem.ca': 90,
#    'Quisque@sitametnulla.co.uk': 89,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 89,
#    'Nunc.laoreet@adlitora.net': 85,
#    'magnis.dis@fringillapurus.org': 91,
#    'quis@Suspendisse.net': 81,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 99,
#    'aliquet.metus.urna@interdum.edu': 92,
#    'sem.semper.erat@mattissemper.net': 98,
#    'Fusce@risus.co.uk': 99,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 89,
#    'erat@auguemalesuada.net': 21,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 61,
#    'et@turpisegestasAliquam.org': 88,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 82,
#    'adipiscing.elit@eutellusPhasellus.edu': 91,
#    'cursus.a@feugiattelluslorem.edu': 93,
#    'adipiscing@lobortisnisi.com': 96},
#   7: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 81,
#    'orci.quis@dignissim.ca': 92,
#    'dui@enim.ca': 94,
#    'eu@Craseget.com': 99,
#    'aliquet.vel@Vestibulum.org': 77,
#    'at@massa.net': 90,
#    'in@iaculis.org': 18,
#    'porttitor.eros@ametdapibus.com': 73,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 93,
#    'Curabitur.egestas.nunc@erat.org': 85,
#    'ante.ipsum@Phasellusat.edu': 91,
#    'faucibus@elitNulla.edu': 65,
#    'Nunc.ullamcorper@aceleifend.net': 98,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 85,
#    'turpis@milorem.ca': 71,
#    'semper.auctor.Mauris@Maurismagna.com': 77,
#    'blandit@augue.ca': 97,
#    'tellus.imperdiet@necmetus.net': 86,
#    'dui.quis@pretiumneque.com': 91,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 99,
#    'sit@duiSuspendisse.edu': 67,
#    'pede.Nunc.sed@justoProin.co.uk': 42,
#    'eu.ultrices.sit@tempuseu.ca': 78,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 80,
#    'ut.nulla@Aliquam.edu': 87,
#    'sem.Nulla@lacuspedesagittis.co.uk': 82,
#    'Integer.tincidunt.aliquam@enim.ca': 98,
#    'convallis.convallis@facilisi.edu': 97,
#    'Etiam.laoreet.libero@amet.org': 94,
#    'pede@pharetrasedhendrerit.co.uk': 96,
#    'congue.a@eudoloregestas.edu': 88,
#    'gravida.Aliquam.tincidunt@nulla.ca': 98,
#    'vitae@Pellentesque.com': 85,
#    'inceptos@semperet.ca': 82,
#    'nec.cursus@arcuVestibulumante.net': 91,
#    'mauris.Morbi@aliquetnec.edu': 94,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 87,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 3,
#    'Nulla@atauctorullamcorper.com': 79,
#    'Nunc.laoreet@Aliquamrutrum.ca': 88,
#    'a@acarcuNunc.org': 87,
#    'Phasellus.fermentum@Proin.org': 91,
#    'dui.in.sodales@lorem.org': 98,
#    'nisl.Maecenas@justo.com': 96,
#    'volutpat@quis.com': 15,
#    'vitae.orci.Phasellus@turpis.com': 97,
#    'odio@nonmassa.net': 96,
#    'Phasellus.at.augue@eu.co.uk': 87,
#    'vel@enimnonnisi.com': 95,
#    'orci@purusDuiselementum.ca': 80,
#    'Pellentesque@eros.ca': 82,
#    'Mauris.non.dui@blanditatnisi.edu': 85,
#    'Fusce@vitae.ca': 77,
#    'malesuada.Integer@ornareplacerat.com': 82,
#    'id.ante@tellus.net': 86,
#    'sem.Nulla@at.edu': 64,
#    'ut.nulla.Cras@nisi.org': 83,
#    'enim.diam.vel@fringillamilacinia.co.uk': 75,
#    'et.commodo@elit.com': 98,
#    'nulla.Integer.urna@tortor.ca': 71,
#    'velit.Quisque@scelerisque.co.uk': 75,
#    'aliquet.sem@non.co.uk': 98,
#    'odio.Aliquam@rhoncus.ca': 96,
#    'non@Proinmi.edu': 93,
#    'lorem.fringilla.ornare@non.com': 81,
#    'ante@auctorMauris.edu': 82,
#    'ullamcorper.Duis.at@netus.org': 92,
#    'non.massa.non@Morbivehicula.org': 90,
#    'Maecenas.mi@Etiamvestibulum.ca': 68,
#    'Quisque.porttitor.eros@enimMauris.ca': 70,
#    'consequat.purus.Maecenas@eratSed.com': 85,
#    'mi@felis.edu': 15,
#    'orci@metus.edu': 87,
#    'aliquet.libero.Integer@lectussit.net': 91,
#    'vel@id.ca': 89,
#    'ipsum.sodales@purusmauris.edu': 96,
#    'ac@cubiliaCuraePhasellus.org': 97,
#    'Donec.dignissim@luctus.ca': 85,
#    'libero@sagittislobortismauris.net': 87,
#    'sed@quamquisdiam.edu': 98,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 96,
#    'Proin@vitae.net': 99,
#    'magna.Sed.eu@loremlorem.ca': 84,
#    'Quisque@sitametnulla.co.uk': 93,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 100,
#    'Nunc.laoreet@adlitora.net': 77,
#    'magnis.dis@fringillapurus.org': 85,
#    'quis@Suspendisse.net': 85,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 86,
#    'aliquet.metus.urna@interdum.edu': 90,
#    'sem.semper.erat@mattissemper.net': 68,
#    'Fusce@risus.co.uk': 81,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 99,
#    'erat@auguemalesuada.net': 85,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 95,
#    'et@turpisegestasAliquam.org': 97,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 78,
#    'adipiscing.elit@eutellusPhasellus.edu': 95,
#    'cursus.a@feugiattelluslorem.edu': 98,
#    'adipiscing@lobortisnisi.com': 81},
#   8: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 89,
#    'orci.quis@dignissim.ca': 95,
#    'dui@enim.ca': 97,
#    'eu@Craseget.com': 53,
#    'aliquet.vel@Vestibulum.org': 96,
#    'at@massa.net': 60,
#    'in@iaculis.org': 100,
#    'porttitor.eros@ametdapibus.com': 73,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 92,
#    'Curabitur.egestas.nunc@erat.org': 97,
#    'ante.ipsum@Phasellusat.edu': 92,
#    'faucibus@elitNulla.edu': 94,
#    'Nunc.ullamcorper@aceleifend.net': 70,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 98,
#    'turpis@milorem.ca': 91,
#    'semper.auctor.Mauris@Maurismagna.com': 8,
#    'blandit@augue.ca': 98,
#    'tellus.imperdiet@necmetus.net': 81,
#    'dui.quis@pretiumneque.com': 62,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 90,
#    'sit@duiSuspendisse.edu': 71,
#    'pede.Nunc.sed@justoProin.co.uk': 97,
#    'eu.ultrices.sit@tempuseu.ca': 88,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 85,
#    'ut.nulla@Aliquam.edu': 71,
#    'sem.Nulla@lacuspedesagittis.co.uk': 81,
#    'Integer.tincidunt.aliquam@enim.ca': 96,
#    'convallis.convallis@facilisi.edu': 98,
#    'Etiam.laoreet.libero@amet.org': 69,
#    'pede@pharetrasedhendrerit.co.uk': 90,
#    'congue.a@eudoloregestas.edu': 89,
#    'gravida.Aliquam.tincidunt@nulla.ca': 87,
#    'vitae@Pellentesque.com': 84,
#    'inceptos@semperet.ca': 62,
#    'nec.cursus@arcuVestibulumante.net': 98,
#    'mauris.Morbi@aliquetnec.edu': 96,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 95,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 87,
#    'Nulla@atauctorullamcorper.com': 94,
#    'Nunc.laoreet@Aliquamrutrum.ca': 86,
#    'a@acarcuNunc.org': 91,
#    'Phasellus.fermentum@Proin.org': 63,
#    'dui.in.sodales@lorem.org': 91,
#    'nisl.Maecenas@justo.com': 80,
#    'volutpat@quis.com': 68,
#    'vitae.orci.Phasellus@turpis.com': 100,
#    'odio@nonmassa.net': 97,
#    'Phasellus.at.augue@eu.co.uk': 86,
#    'vel@enimnonnisi.com': 85,
#    'orci@purusDuiselementum.ca': 22,
#    'Pellentesque@eros.ca': 71,
#    'Mauris.non.dui@blanditatnisi.edu': 79,
#    'Fusce@vitae.ca': 80,
#    'malesuada.Integer@ornareplacerat.com': 60,
#    'id.ante@tellus.net': 83,
#    'sem.Nulla@at.edu': 75,
#    'ut.nulla.Cras@nisi.org': 95,
#    'enim.diam.vel@fringillamilacinia.co.uk': 99,
#    'et.commodo@elit.com': 9,
#    'nulla.Integer.urna@tortor.ca': 99,
#    'velit.Quisque@scelerisque.co.uk': 91,
#    'aliquet.sem@non.co.uk': 81,
#    'odio.Aliquam@rhoncus.ca': 80,
#    'non@Proinmi.edu': 99,
#    'lorem.fringilla.ornare@non.com': 96,
#    'ante@auctorMauris.edu': 97,
#    'ullamcorper.Duis.at@netus.org': 90,
#    'non.massa.non@Morbivehicula.org': 61,
#    'Maecenas.mi@Etiamvestibulum.ca': 80,
#    'Quisque.porttitor.eros@enimMauris.ca': 94,
#    'consequat.purus.Maecenas@eratSed.com': 96,
#    'mi@felis.edu': 94,
#    'orci@metus.edu': 94,
#    'aliquet.libero.Integer@lectussit.net': 75,
#    'vel@id.ca': 92,
#    'ipsum.sodales@purusmauris.edu': 91,
#    'ac@cubiliaCuraePhasellus.org': 99,
#    'Donec.dignissim@luctus.ca': 99,
#    'libero@sagittislobortismauris.net': 80,
#    'sed@quamquisdiam.edu': 81,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 87,
#    'Proin@vitae.net': 97,
#    'magna.Sed.eu@loremlorem.ca': 60,
#    'Quisque@sitametnulla.co.uk': 92,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 96,
#    'Nunc.laoreet@adlitora.net': 46,
#    'magnis.dis@fringillapurus.org': 92,
#    'quis@Suspendisse.net': 77,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 93,
#    'aliquet.metus.urna@interdum.edu': 89,
#    'sem.semper.erat@mattissemper.net': 69,
#    'Fusce@risus.co.uk': 80,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 87,
#    'erat@auguemalesuada.net': 91,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 73,
#    'et@turpisegestasAliquam.org': 85,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 75,
#    'adipiscing.elit@eutellusPhasellus.edu': 100,
#    'cursus.a@feugiattelluslorem.edu': 93,
#    'adipiscing@lobortisnisi.com': 91},
#   9: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 93,
#    'orci.quis@dignissim.ca': 95,
#    'dui@enim.ca': 72,
#    'eu@Craseget.com': 82,
#    'aliquet.vel@Vestibulum.org': 96,
#    'at@massa.net': 94,
#    'in@iaculis.org': 74,
#    'porttitor.eros@ametdapibus.com': 93,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 90,
#    'Curabitur.egestas.nunc@erat.org': 96,
#    'ante.ipsum@Phasellusat.edu': 84,
#    'faucibus@elitNulla.edu': 98,
#    'Nunc.ullamcorper@aceleifend.net': 89,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 96,
#    'turpis@milorem.ca': 88,
#    'semper.auctor.Mauris@Maurismagna.com': 91,
#    'blandit@augue.ca': 70,
#    'tellus.imperdiet@necmetus.net': 77,
#    'dui.quis@pretiumneque.com': 85,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 90,
#    'sit@duiSuspendisse.edu': 85,
#    'pede.Nunc.sed@justoProin.co.uk': 73,
#    'eu.ultrices.sit@tempuseu.ca': 96,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 97,
#    'ut.nulla@Aliquam.edu': 92,
#    'sem.Nulla@lacuspedesagittis.co.uk': 86,
#    'Integer.tincidunt.aliquam@enim.ca': 95,
#    'convallis.convallis@facilisi.edu': 86,
#    'Etiam.laoreet.libero@amet.org': 99,
#    'pede@pharetrasedhendrerit.co.uk': 80,
#    'congue.a@eudoloregestas.edu': 88,
#    'gravida.Aliquam.tincidunt@nulla.ca': 93,
#    'vitae@Pellentesque.com': 80,
#    'inceptos@semperet.ca': 93,
#    'nec.cursus@arcuVestibulumante.net': 89,
#    'mauris.Morbi@aliquetnec.edu': 99,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 94,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 99,
#    'Nulla@atauctorullamcorper.com': 92,
#    'Nunc.laoreet@Aliquamrutrum.ca': 97,
#    'a@acarcuNunc.org': 82,
#    'Phasellus.fermentum@Proin.org': 74,
#    'dui.in.sodales@lorem.org': 94,
#    'nisl.Maecenas@justo.com': 21,
#    'volutpat@quis.com': 73,
#    'vitae.orci.Phasellus@turpis.com': 22,
#    'odio@nonmassa.net': 80,
#    'Phasellus.at.augue@eu.co.uk': 93,
#    'vel@enimnonnisi.com': 70,
#    'orci@purusDuiselementum.ca': 90,
#    'Pellentesque@eros.ca': 99,
#    'Mauris.non.dui@blanditatnisi.edu': 83,
#    'Fusce@vitae.ca': 60,
#    'malesuada.Integer@ornareplacerat.com': 92,
#    'id.ante@tellus.net': 92,
#    'sem.Nulla@at.edu': 81,
#    'ut.nulla.Cras@nisi.org': 82,
#    'enim.diam.vel@fringillamilacinia.co.uk': 91,
#    'et.commodo@elit.com': 95,
#    'nulla.Integer.urna@tortor.ca': 95,
#    'velit.Quisque@scelerisque.co.uk': 89,
#    'aliquet.sem@non.co.uk': 88,
#    'odio.Aliquam@rhoncus.ca': 96,
#    'non@Proinmi.edu': 89,
#    'lorem.fringilla.ornare@non.com': 72,
#    'ante@auctorMauris.edu': 78,
#    'ullamcorper.Duis.at@netus.org': 99,
#    'non.massa.non@Morbivehicula.org': 94,
#    'Maecenas.mi@Etiamvestibulum.ca': 87,
#    'Quisque.porttitor.eros@enimMauris.ca': 70,
#    'consequat.purus.Maecenas@eratSed.com': 93,
#    'mi@felis.edu': 93,
#    'orci@metus.edu': 85,
#    'aliquet.libero.Integer@lectussit.net': 96,
#    'vel@id.ca': 98,
#    'ipsum.sodales@purusmauris.edu': 85,
#    'ac@cubiliaCuraePhasellus.org': 90,
#    'Donec.dignissim@luctus.ca': 83,
#    'libero@sagittislobortismauris.net': 97,
#    'sed@quamquisdiam.edu': 88,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 88,
#    'Proin@vitae.net': 74,
#    'magna.Sed.eu@loremlorem.ca': 97,
#    'Quisque@sitametnulla.co.uk': 85,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 95,
#    'Nunc.laoreet@adlitora.net': 86,
#    'magnis.dis@fringillapurus.org': 85,
#    'quis@Suspendisse.net': 76,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 98,
#    'aliquet.metus.urna@interdum.edu': 60,
#    'sem.semper.erat@mattissemper.net': 84,
#    'Fusce@risus.co.uk': 96,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 97,
#    'erat@auguemalesuada.net': 72,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 86,
#    'et@turpisegestasAliquam.org': 100,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 94,
#    'adipiscing.elit@eutellusPhasellus.edu': 86,
#    'cursus.a@feugiattelluslorem.edu': 69,
#    'adipiscing@lobortisnisi.com': 87}},
#  'quizzes': {1: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 94,
#    'orci.quis@dignissim.ca': 82,
#    'dui@enim.ca': 95,
#    'eu@Craseget.com': 98,
#    'aliquet.vel@Vestibulum.org': 83,
#    'at@massa.net': 92,
#    'in@iaculis.org': 85,
#    'porttitor.eros@ametdapibus.com': 93,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 68,
#    'Curabitur.egestas.nunc@erat.org': 84,
#    'ante.ipsum@Phasellusat.edu': 94,
#    'faucibus@elitNulla.edu': 100,
#    'Nunc.ullamcorper@aceleifend.net': 82,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 72,
#    'turpis@milorem.ca': 94,
#    'semper.auctor.Mauris@Maurismagna.com': 76,
#    'blandit@augue.ca': 92,
#    'tellus.imperdiet@necmetus.net': 98,
#    'dui.quis@pretiumneque.com': 85,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 61,
#    'sit@duiSuspendisse.edu': 82,
#    'pede.Nunc.sed@justoProin.co.uk': 82,
#    'eu.ultrices.sit@tempuseu.ca': 86,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 49,
#    'ut.nulla@Aliquam.edu': 84,
#    'sem.Nulla@lacuspedesagittis.co.uk': 99,
#    'Integer.tincidunt.aliquam@enim.ca': 91,
#    'convallis.convallis@facilisi.edu': 68,
#    'Etiam.laoreet.libero@amet.org': 73,
#    'pede@pharetrasedhendrerit.co.uk': 95,
#    'congue.a@eudoloregestas.edu': 95,
#    'gravida.Aliquam.tincidunt@nulla.ca': 95,
#    'vitae@Pellentesque.com': 8,
#    'inceptos@semperet.ca': 82,
#    'nec.cursus@arcuVestibulumante.net': 94,
#    'mauris.Morbi@aliquetnec.edu': 68,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 89,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 70,
#    'Nulla@atauctorullamcorper.com': 97,
#    'Nunc.laoreet@Aliquamrutrum.ca': 28,
#    'a@acarcuNunc.org': 92,
#    'Phasellus.fermentum@Proin.org': 80,
#    'dui.in.sodales@lorem.org': 95,
#    'nisl.Maecenas@justo.com': 99,
#    'volutpat@quis.com': 86,
#    'vitae.orci.Phasellus@turpis.com': 94,
#    'odio@nonmassa.net': 89,
#    'Phasellus.at.augue@eu.co.uk': 37,
#    'vel@enimnonnisi.com': 64,
#    'orci@purusDuiselementum.ca': 39,
#    'Pellentesque@eros.ca': 25,
#    'Mauris.non.dui@blanditatnisi.edu': 94,
#    'Fusce@vitae.ca': 78,
#    'malesuada.Integer@ornareplacerat.com': 85,
#    'id.ante@tellus.net': 18,
#    'sem.Nulla@at.edu': 85,
#    'ut.nulla.Cras@nisi.org': 90,
#    'enim.diam.vel@fringillamilacinia.co.uk': 88,
#    'et.commodo@elit.com': 94,
#    'nulla.Integer.urna@tortor.ca': 96,
#    'velit.Quisque@scelerisque.co.uk': 99,
#    'aliquet.sem@non.co.uk': 99,
#    'odio.Aliquam@rhoncus.ca': 34,
#    'non@Proinmi.edu': 95,
#    'lorem.fringilla.ornare@non.com': 95,
#    'ante@auctorMauris.edu': 74,
#    'ullamcorper.Duis.at@netus.org': 76,
#    'non.massa.non@Morbivehicula.org': 98,
#    'Maecenas.mi@Etiamvestibulum.ca': 99,
#    'Quisque.porttitor.eros@enimMauris.ca': 92,
#    'consequat.purus.Maecenas@eratSed.com': 99,
#    'mi@felis.edu': 91,
#    'orci@metus.edu': 96,
#    'aliquet.libero.Integer@lectussit.net': 97,
#    'vel@id.ca': 98,
#    'ipsum.sodales@purusmauris.edu': 86,
#    'ac@cubiliaCuraePhasellus.org': 90,
#    'Donec.dignissim@luctus.ca': 96,
#    'libero@sagittislobortismauris.net': 9,
#    'sed@quamquisdiam.edu': 66,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 65,
#    'Proin@vitae.net': 74,
#    'magna.Sed.eu@loremlorem.ca': 95,
#    'Quisque@sitametnulla.co.uk': 93,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 92,
#    'Nunc.laoreet@adlitora.net': 92,
#    'magnis.dis@fringillapurus.org': 86,
#    'quis@Suspendisse.net': 35,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 77,
#    'aliquet.metus.urna@interdum.edu': 82,
#    'sem.semper.erat@mattissemper.net': 99,
#    'Fusce@risus.co.uk': 88,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 65,
#    'erat@auguemalesuada.net': 71,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 98,
#    'et@turpisegestasAliquam.org': 60,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 99,
#    'adipiscing.elit@eutellusPhasellus.edu': 49,
#    'cursus.a@feugiattelluslorem.edu': 10,
#    'adipiscing@lobortisnisi.com': 65},
#   2: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 90,
#    'orci.quis@dignissim.ca': 93,
#    'dui@enim.ca': 72,
#    'eu@Craseget.com': 74,
#    'aliquet.vel@Vestibulum.org': 75,
#    'at@massa.net': 83,
#    'in@iaculis.org': 90,
#    'porttitor.eros@ametdapibus.com': 86,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 0,
#    'Curabitur.egestas.nunc@erat.org': 87,
#    'ante.ipsum@Phasellusat.edu': 63,
#    'faucibus@elitNulla.edu': 91,
#    'Nunc.ullamcorper@aceleifend.net': 100,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 92,
#    'turpis@milorem.ca': 80,
#    'semper.auctor.Mauris@Maurismagna.com': 86,
#    'blandit@augue.ca': 92,
#    'tellus.imperdiet@necmetus.net': 96,
#    'dui.quis@pretiumneque.com': 92,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 98,
#    'sit@duiSuspendisse.edu': 97,
#    'pede.Nunc.sed@justoProin.co.uk': 0,
#    'eu.ultrices.sit@tempuseu.ca': 88,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 90,
#    'ut.nulla@Aliquam.edu': 70,
#    'sem.Nulla@lacuspedesagittis.co.uk': 80,
#    'Integer.tincidunt.aliquam@enim.ca': 61,
#    'convallis.convallis@facilisi.edu': 73,
#    'Etiam.laoreet.libero@amet.org': 100,
#    'pede@pharetrasedhendrerit.co.uk': 85,
#    'congue.a@eudoloregestas.edu': 91,
#    'gravida.Aliquam.tincidunt@nulla.ca': 82,
#    'vitae@Pellentesque.com': 28,
#    'inceptos@semperet.ca': 94,
#    'nec.cursus@arcuVestibulumante.net': 70,
#    'mauris.Morbi@aliquetnec.edu': 90,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 85,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 98,
#    'Nulla@atauctorullamcorper.com': 16,
#    'Nunc.laoreet@Aliquamrutrum.ca': 61,
#    'a@acarcuNunc.org': 100,
#    'Phasellus.fermentum@Proin.org': 99,
#    'dui.in.sodales@lorem.org': 88,
#    'nisl.Maecenas@justo.com': 82,
#    'volutpat@quis.com': 78,
#    'vitae.orci.Phasellus@turpis.com': 89,
#    'odio@nonmassa.net': 100,
#    'Phasellus.at.augue@eu.co.uk': 96,
#    'vel@enimnonnisi.com': 84,
#    'orci@purusDuiselementum.ca': 92,
#    'Pellentesque@eros.ca': 50,
#    'Mauris.non.dui@blanditatnisi.edu': 89,
#    'Fusce@vitae.ca': 75,
#    'malesuada.Integer@ornareplacerat.com': 93,
#    'id.ante@tellus.net': 90,
#    'sem.Nulla@at.edu': 76,
#    'ut.nulla.Cras@nisi.org': 88,
#    'enim.diam.vel@fringillamilacinia.co.uk': 82,
#    'et.commodo@elit.com': 81,
#    'nulla.Integer.urna@tortor.ca': 88,
#    'velit.Quisque@scelerisque.co.uk': 97,
#    'aliquet.sem@non.co.uk': 61,
#    'odio.Aliquam@rhoncus.ca': 83,
#    'non@Proinmi.edu': 84,
#    'lorem.fringilla.ornare@non.com': 93,
#    'ante@auctorMauris.edu': 80,
#    'ullamcorper.Duis.at@netus.org': 69,
#    'non.massa.non@Morbivehicula.org': 93,
#    'Maecenas.mi@Etiamvestibulum.ca': 93,
#    'Quisque.porttitor.eros@enimMauris.ca': 100,
#    'consequat.purus.Maecenas@eratSed.com': 79,
#    'mi@felis.edu': 93,
#    'orci@metus.edu': 84,
#    'aliquet.libero.Integer@lectussit.net': 74,
#    'vel@id.ca': 91,
#    'ipsum.sodales@purusmauris.edu': 81,
#    'ac@cubiliaCuraePhasellus.org': 89,
#    'Donec.dignissim@luctus.ca': 94,
#    'libero@sagittislobortismauris.net': 82,
#    'sed@quamquisdiam.edu': 99,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 52,
#    'Proin@vitae.net': 82,
#    'magna.Sed.eu@loremlorem.ca': 91,
#    'Quisque@sitametnulla.co.uk': 87,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 90,
#    'Nunc.laoreet@adlitora.net': 76,
#    'magnis.dis@fringillapurus.org': 90,
#    'quis@Suspendisse.net': 92,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 58,
#    'aliquet.metus.urna@interdum.edu': 13,
#    'sem.semper.erat@mattissemper.net': 98,
#    'Fusce@risus.co.uk': 90,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 100,
#    'erat@auguemalesuada.net': 48,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 80,
#    'et@turpisegestasAliquam.org': 93,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 94,
#    'adipiscing.elit@eutellusPhasellus.edu': 97,
#    'cursus.a@feugiattelluslorem.edu': 99,
#    'adipiscing@lobortisnisi.com': 97},
#   3: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 83,
#    'orci.quis@dignissim.ca': 95,
#    'dui@enim.ca': 94,
#    'eu@Craseget.com': 73,
#    'aliquet.vel@Vestibulum.org': 84,
#    'at@massa.net': 92,
#    'in@iaculis.org': 80,
#    'porttitor.eros@ametdapibus.com': 96,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 94,
#    'Curabitur.egestas.nunc@erat.org': 93,
#    'ante.ipsum@Phasellusat.edu': 88,
#    'faucibus@elitNulla.edu': 82,
#    'Nunc.ullamcorper@aceleifend.net': 91,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 94,
#    'turpis@milorem.ca': 100,
#    'semper.auctor.Mauris@Maurismagna.com': 94,
#    'blandit@augue.ca': 96,
#    'tellus.imperdiet@necmetus.net': 84,
#    'dui.quis@pretiumneque.com': 78,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 95,
#    'sit@duiSuspendisse.edu': 72,
#    'pede.Nunc.sed@justoProin.co.uk': 91,
#    'eu.ultrices.sit@tempuseu.ca': 88,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 99,
#    'ut.nulla@Aliquam.edu': 91,
#    'sem.Nulla@lacuspedesagittis.co.uk': 98,
#    'Integer.tincidunt.aliquam@enim.ca': 94,
#    'convallis.convallis@facilisi.edu': 91,
#    'Etiam.laoreet.libero@amet.org': 80,
#    'pede@pharetrasedhendrerit.co.uk': 83,
#    'congue.a@eudoloregestas.edu': 87,
#    'gravida.Aliquam.tincidunt@nulla.ca': 99,
#    'vitae@Pellentesque.com': 74,
#    'inceptos@semperet.ca': 89,
#    'nec.cursus@arcuVestibulumante.net': 91,
#    'mauris.Morbi@aliquetnec.edu': 86,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 89,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 78,
#    'Nulla@atauctorullamcorper.com': 92,
#    'Nunc.laoreet@Aliquamrutrum.ca': 90,
#    'a@acarcuNunc.org': 63,
#    'Phasellus.fermentum@Proin.org': 86,
#    'dui.in.sodales@lorem.org': 99,
#    'nisl.Maecenas@justo.com': 84,
#    'volutpat@quis.com': 73,
#    'vitae.orci.Phasellus@turpis.com': 75,
#    'odio@nonmassa.net': 91,
#    'Phasellus.at.augue@eu.co.uk': 78,
#    'vel@enimnonnisi.com': 61,
#    'orci@purusDuiselementum.ca': 77,
#    'Pellentesque@eros.ca': 76,
#    'Mauris.non.dui@blanditatnisi.edu': 100,
#    'Fusce@vitae.ca': 89,
#    'malesuada.Integer@ornareplacerat.com': 85,
#    'id.ante@tellus.net': 91,
#    'sem.Nulla@at.edu': 95,
#    'ut.nulla.Cras@nisi.org': 96,
#    'enim.diam.vel@fringillamilacinia.co.uk': 98,
#    'et.commodo@elit.com': 65,
#    'nulla.Integer.urna@tortor.ca': 95,
#    'velit.Quisque@scelerisque.co.uk': 99,
#    'aliquet.sem@non.co.uk': 94,
#    'odio.Aliquam@rhoncus.ca': 71,
#    'non@Proinmi.edu': 92,
#    'lorem.fringilla.ornare@non.com': 89,
#    'ante@auctorMauris.edu': 63,
#    'ullamcorper.Duis.at@netus.org': 97,
#    'non.massa.non@Morbivehicula.org': 82,
#    'Maecenas.mi@Etiamvestibulum.ca': 83,
#    'Quisque.porttitor.eros@enimMauris.ca': 86,
#    'consequat.purus.Maecenas@eratSed.com': 82,
#    'mi@felis.edu': 87,
#    'orci@metus.edu': 49,
#    'aliquet.libero.Integer@lectussit.net': 85,
#    'vel@id.ca': 95,
#    'ipsum.sodales@purusmauris.edu': 36,
#    'ac@cubiliaCuraePhasellus.org': 98,
#    'Donec.dignissim@luctus.ca': 96,
#    'libero@sagittislobortismauris.net': 94,
#    'sed@quamquisdiam.edu': 87,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 83,
#    'Proin@vitae.net': 72,
#    'magna.Sed.eu@loremlorem.ca': 92,
#    'Quisque@sitametnulla.co.uk': 82,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 91,
#    'Nunc.laoreet@adlitora.net': 80,
#    'magnis.dis@fringillapurus.org': 97,
#    'quis@Suspendisse.net': 99,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 97,
#    'aliquet.metus.urna@interdum.edu': 80,
#    'sem.semper.erat@mattissemper.net': 87,
#    'Fusce@risus.co.uk': 97,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 83,
#    'erat@auguemalesuada.net': 91,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 6,
#    'et@turpisegestasAliquam.org': 71,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 99,
#    'adipiscing.elit@eutellusPhasellus.edu': 96,
#    'cursus.a@feugiattelluslorem.edu': 76,
#    'adipiscing@lobortisnisi.com': 97}}}

# %% [markdown]
# After all that fuss implementing an XML parser, we could have just used one that comes with Python.  Here's an example showing how.

# %%
import xml.etree.ElementTree as ET

def assignmentFromXmlEasier(xml):
    number = int(xml.find("number").text)
    students = {child.find("email").text: int(child.find("grade").text)
                for child in xml.findall("student")}

    return {"number": number, "students": students}

def categoryFromXmlEasier(xml, singular):
        return {item["number"]: item["students"]
                for child in xml.findall(singular)
                for item in [assignmentFromXmlEasier(child)]}

def gradesFromXmlEasier(xml):
        return {"psets": categoryFromXmlEasier(xml.find("psets"), "pset"),
                "quizzes": categoryFromXmlEasier(xml.find("quizzes"), "quiz")}

def parseGradesEasier(filename):
        return gradesFromXmlEasier(ET.parse(filename).getroot())

# %%
parseGradesEasier('grades.xml')
# Out:
# {'psets': {1: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 100,
#    'orci.quis@dignissim.ca': 79,
#    'dui@enim.ca': 96,
#    'eu@Craseget.com': 82,
#    'aliquet.vel@Vestibulum.org': 94,
#    'at@massa.net': 87,
#    'in@iaculis.org': 18,
#    'porttitor.eros@ametdapibus.com': 100,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 85,
#    'Curabitur.egestas.nunc@erat.org': 97,
#    'ante.ipsum@Phasellusat.edu': 69,
#    'faucibus@elitNulla.edu': 80,
#    'Nunc.ullamcorper@aceleifend.net': 87,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 86,
#    'turpis@milorem.ca': 99,
#    'semper.auctor.Mauris@Maurismagna.com': 73,
#    'blandit@augue.ca': 93,
#    'tellus.imperdiet@necmetus.net': 82,
#    'dui.quis@pretiumneque.com': 97,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 94,
#    'sit@duiSuspendisse.edu': 88,
#    'pede.Nunc.sed@justoProin.co.uk': 93,
#    'eu.ultrices.sit@tempuseu.ca': 55,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 85,
#    'ut.nulla@Aliquam.edu': 72,
#    'sem.Nulla@lacuspedesagittis.co.uk': 83,
#    'Integer.tincidunt.aliquam@enim.ca': 98,
#    'convallis.convallis@facilisi.edu': 86,
#    'Etiam.laoreet.libero@amet.org': 76,
#    'pede@pharetrasedhendrerit.co.uk': 92,
#    'congue.a@eudoloregestas.edu': 94,
#    'gravida.Aliquam.tincidunt@nulla.ca': 92,
#    'vitae@Pellentesque.com': 100,
#    'inceptos@semperet.ca': 100,
#    'nec.cursus@arcuVestibulumante.net': 94,
#    'mauris.Morbi@aliquetnec.edu': 11,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 99,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 93,
#    'Nulla@atauctorullamcorper.com': 93,
#    'Nunc.laoreet@Aliquamrutrum.ca': 66,
#    'a@acarcuNunc.org': 90,
#    'Phasellus.fermentum@Proin.org': 95,
#    'dui.in.sodales@lorem.org': 98,
#    'nisl.Maecenas@justo.com': 97,
#    'volutpat@quis.com': 96,
#    'vitae.orci.Phasellus@turpis.com': 93,
#    'odio@nonmassa.net': 49,
#    'Phasellus.at.augue@eu.co.uk': 61,
#    'vel@enimnonnisi.com': 97,
#    'orci@purusDuiselementum.ca': 93,
#    'Pellentesque@eros.ca': 99,
#    'Mauris.non.dui@blanditatnisi.edu': 91,
#    'Fusce@vitae.ca': 95,
#    'malesuada.Integer@ornareplacerat.com': 25,
#    'id.ante@tellus.net': 96,
#    'sem.Nulla@at.edu': 96,
#    'ut.nulla.Cras@nisi.org': 77,
#    'enim.diam.vel@fringillamilacinia.co.uk': 84,
#    'et.commodo@elit.com': 95,
#    'nulla.Integer.urna@tortor.ca': 99,
#    'velit.Quisque@scelerisque.co.uk': 87,
#    'aliquet.sem@non.co.uk': 94,
#    'odio.Aliquam@rhoncus.ca': 81,
#    'non@Proinmi.edu': 89,
#    'lorem.fringilla.ornare@non.com': 94,
#    'ante@auctorMauris.edu': 94,
#    'ullamcorper.Duis.at@netus.org': 66,
#    'non.massa.non@Morbivehicula.org': 94,
#    'Maecenas.mi@Etiamvestibulum.ca': 14,
#    'Quisque.porttitor.eros@enimMauris.ca': 76,
#    'consequat.purus.Maecenas@eratSed.com': 93,
#    'mi@felis.edu': 53,
#    'orci@metus.edu': 97,
#    'aliquet.libero.Integer@lectussit.net': 86,
#    'vel@id.ca': 99,
#    'ipsum.sodales@purusmauris.edu': 100,
#    'ac@cubiliaCuraePhasellus.org': 72,
#    'Donec.dignissim@luctus.ca': 60,
#    'libero@sagittislobortismauris.net': 98,
#    'sed@quamquisdiam.edu': 91,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 82,
#    'Proin@vitae.net': 82,
#    'magna.Sed.eu@loremlorem.ca': 84,
#    'Quisque@sitametnulla.co.uk': 90,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 94,
#    'Nunc.laoreet@adlitora.net': 86,
#    'magnis.dis@fringillapurus.org': 45,
#    'quis@Suspendisse.net': 80,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 100,
#    'aliquet.metus.urna@interdum.edu': 95,
#    'sem.semper.erat@mattissemper.net': 98,
#    'Fusce@risus.co.uk': 99,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 89,
#    'erat@auguemalesuada.net': 80,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 97,
#    'et@turpisegestasAliquam.org': 88,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 96,
#    'adipiscing.elit@eutellusPhasellus.edu': 91,
#    'cursus.a@feugiattelluslorem.edu': 89,
#    'adipiscing@lobortisnisi.com': 98},
#   2: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 95,
#    'orci.quis@dignissim.ca': 85,
#    'dui@enim.ca': 79,
#    'eu@Craseget.com': 64,
#    'aliquet.vel@Vestibulum.org': 91,
#    'at@massa.net': 98,
#    'in@iaculis.org': 95,
#    'porttitor.eros@ametdapibus.com': 85,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 33,
#    'Curabitur.egestas.nunc@erat.org': 100,
#    'ante.ipsum@Phasellusat.edu': 93,
#    'faucibus@elitNulla.edu': 89,
#    'Nunc.ullamcorper@aceleifend.net': 77,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 92,
#    'turpis@milorem.ca': 81,
#    'semper.auctor.Mauris@Maurismagna.com': 92,
#    'blandit@augue.ca': 97,
#    'tellus.imperdiet@necmetus.net': 75,
#    'dui.quis@pretiumneque.com': 97,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 62,
#    'sit@duiSuspendisse.edu': 97,
#    'pede.Nunc.sed@justoProin.co.uk': 88,
#    'eu.ultrices.sit@tempuseu.ca': 84,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 83,
#    'ut.nulla@Aliquam.edu': 95,
#    'sem.Nulla@lacuspedesagittis.co.uk': 85,
#    'Integer.tincidunt.aliquam@enim.ca': 82,
#    'convallis.convallis@facilisi.edu': 93,
#    'Etiam.laoreet.libero@amet.org': 100,
#    'pede@pharetrasedhendrerit.co.uk': 81,
#    'congue.a@eudoloregestas.edu': 88,
#    'gravida.Aliquam.tincidunt@nulla.ca': 78,
#    'vitae@Pellentesque.com': 95,
#    'inceptos@semperet.ca': 91,
#    'nec.cursus@arcuVestibulumante.net': 100,
#    'mauris.Morbi@aliquetnec.edu': 57,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 86,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 99,
#    'Nulla@atauctorullamcorper.com': 46,
#    'Nunc.laoreet@Aliquamrutrum.ca': 91,
#    'a@acarcuNunc.org': 88,
#    'Phasellus.fermentum@Proin.org': 90,
#    'dui.in.sodales@lorem.org': 91,
#    'nisl.Maecenas@justo.com': 91,
#    'volutpat@quis.com': 95,
#    'vitae.orci.Phasellus@turpis.com': 96,
#    'odio@nonmassa.net': 100,
#    'Phasellus.at.augue@eu.co.uk': 93,
#    'vel@enimnonnisi.com': 80,
#    'orci@purusDuiselementum.ca': 75,
#    'Pellentesque@eros.ca': 92,
#    'Mauris.non.dui@blanditatnisi.edu': 73,
#    'Fusce@vitae.ca': 96,
#    'malesuada.Integer@ornareplacerat.com': 94,
#    'id.ante@tellus.net': 90,
#    'sem.Nulla@at.edu': 65,
#    'ut.nulla.Cras@nisi.org': 83,
#    'enim.diam.vel@fringillamilacinia.co.uk': 73,
#    'et.commodo@elit.com': 100,
#    'nulla.Integer.urna@tortor.ca': 88,
#    'velit.Quisque@scelerisque.co.uk': 78,
#    'aliquet.sem@non.co.uk': 96,
#    'odio.Aliquam@rhoncus.ca': 82,
#    'non@Proinmi.edu': 80,
#    'lorem.fringilla.ornare@non.com': 88,
#    'ante@auctorMauris.edu': 98,
#    'ullamcorper.Duis.at@netus.org': 91,
#    'non.massa.non@Morbivehicula.org': 68,
#    'Maecenas.mi@Etiamvestibulum.ca': 91,
#    'Quisque.porttitor.eros@enimMauris.ca': 84,
#    'consequat.purus.Maecenas@eratSed.com': 91,
#    'mi@felis.edu': 97,
#    'orci@metus.edu': 33,
#    'aliquet.libero.Integer@lectussit.net': 6,
#    'vel@id.ca': 95,
#    'ipsum.sodales@purusmauris.edu': 93,
#    'ac@cubiliaCuraePhasellus.org': 45,
#    'Donec.dignissim@luctus.ca': 96,
#    'libero@sagittislobortismauris.net': 80,
#    'sed@quamquisdiam.edu': 99,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 98,
#    'Proin@vitae.net': 87,
#    'magna.Sed.eu@loremlorem.ca': 95,
#    'Quisque@sitametnulla.co.uk': 87,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 87,
#    'Nunc.laoreet@adlitora.net': 92,
#    'magnis.dis@fringillapurus.org': 75,
#    'quis@Suspendisse.net': 76,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 96,
#    'aliquet.metus.urna@interdum.edu': 81,
#    'sem.semper.erat@mattissemper.net': 90,
#    'Fusce@risus.co.uk': 99,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 97,
#    'erat@auguemalesuada.net': 100,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 98,
#    'et@turpisegestasAliquam.org': 82,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 97,
#    'adipiscing.elit@eutellusPhasellus.edu': 95,
#    'cursus.a@feugiattelluslorem.edu': 95,
#    'adipiscing@lobortisnisi.com': 90},
#   3: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 71,
#    'orci.quis@dignissim.ca': 97,
#    'dui@enim.ca': 95,
#    'eu@Craseget.com': 17,
#    'aliquet.vel@Vestibulum.org': 88,
#    'at@massa.net': 93,
#    'in@iaculis.org': 97,
#    'porttitor.eros@ametdapibus.com': 90,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 89,
#    'Curabitur.egestas.nunc@erat.org': 96,
#    'ante.ipsum@Phasellusat.edu': 79,
#    'faucibus@elitNulla.edu': 96,
#    'Nunc.ullamcorper@aceleifend.net': 94,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 79,
#    'turpis@milorem.ca': 97,
#    'semper.auctor.Mauris@Maurismagna.com': 85,
#    'blandit@augue.ca': 71,
#    'tellus.imperdiet@necmetus.net': 93,
#    'dui.quis@pretiumneque.com': 89,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 70,
#    'sit@duiSuspendisse.edu': 88,
#    'pede.Nunc.sed@justoProin.co.uk': 72,
#    'eu.ultrices.sit@tempuseu.ca': 70,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 97,
#    'ut.nulla@Aliquam.edu': 51,
#    'sem.Nulla@lacuspedesagittis.co.uk': 92,
#    'Integer.tincidunt.aliquam@enim.ca': 95,
#    'convallis.convallis@facilisi.edu': 19,
#    'Etiam.laoreet.libero@amet.org': 91,
#    'pede@pharetrasedhendrerit.co.uk': 98,
#    'congue.a@eudoloregestas.edu': 99,
#    'gravida.Aliquam.tincidunt@nulla.ca': 97,
#    'vitae@Pellentesque.com': 99,
#    'inceptos@semperet.ca': 85,
#    'nec.cursus@arcuVestibulumante.net': 92,
#    'mauris.Morbi@aliquetnec.edu': 90,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 90,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 89,
#    'Nulla@atauctorullamcorper.com': 18,
#    'Nunc.laoreet@Aliquamrutrum.ca': 66,
#    'a@acarcuNunc.org': 60,
#    'Phasellus.fermentum@Proin.org': 100,
#    'dui.in.sodales@lorem.org': 77,
#    'nisl.Maecenas@justo.com': 76,
#    'volutpat@quis.com': 99,
#    'vitae.orci.Phasellus@turpis.com': 63,
#    'odio@nonmassa.net': 92,
#    'Phasellus.at.augue@eu.co.uk': 63,
#    'vel@enimnonnisi.com': 89,
#    'orci@purusDuiselementum.ca': 84,
#    'Pellentesque@eros.ca': 97,
#    'Mauris.non.dui@blanditatnisi.edu': 96,
#    'Fusce@vitae.ca': 23,
#    'malesuada.Integer@ornareplacerat.com': 90,
#    'id.ante@tellus.net': 84,
#    'sem.Nulla@at.edu': 94,
#    'ut.nulla.Cras@nisi.org': 97,
#    'enim.diam.vel@fringillamilacinia.co.uk': 87,
#    'et.commodo@elit.com': 92,
#    'nulla.Integer.urna@tortor.ca': 95,
#    'velit.Quisque@scelerisque.co.uk': 67,
#    'aliquet.sem@non.co.uk': 91,
#    'odio.Aliquam@rhoncus.ca': 93,
#    'non@Proinmi.edu': 84,
#    'lorem.fringilla.ornare@non.com': 100,
#    'ante@auctorMauris.edu': 82,
#    'ullamcorper.Duis.at@netus.org': 92,
#    'non.massa.non@Morbivehicula.org': 96,
#    'Maecenas.mi@Etiamvestibulum.ca': 91,
#    'Quisque.porttitor.eros@enimMauris.ca': 28,
#    'consequat.purus.Maecenas@eratSed.com': 91,
#    'mi@felis.edu': 84,
#    'orci@metus.edu': 98,
#    'aliquet.libero.Integer@lectussit.net': 100,
#    'vel@id.ca': 82,
#    'ipsum.sodales@purusmauris.edu': 92,
#    'ac@cubiliaCuraePhasellus.org': 90,
#    'Donec.dignissim@luctus.ca': 63,
#    'libero@sagittislobortismauris.net': 43,
#    'sed@quamquisdiam.edu': 83,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 98,
#    'Proin@vitae.net': 95,
#    'magna.Sed.eu@loremlorem.ca': 78,
#    'Quisque@sitametnulla.co.uk': 37,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 86,
#    'Nunc.laoreet@adlitora.net': 66,
#    'magnis.dis@fringillapurus.org': 68,
#    'quis@Suspendisse.net': 92,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 99,
#    'aliquet.metus.urna@interdum.edu': 91,
#    'sem.semper.erat@mattissemper.net': 97,
#    'Fusce@risus.co.uk': 90,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 38,
#    'erat@auguemalesuada.net': 99,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 92,
#    'et@turpisegestasAliquam.org': 98,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 74,
#    'adipiscing.elit@eutellusPhasellus.edu': 97,
#    'cursus.a@feugiattelluslorem.edu': 87,
#    'adipiscing@lobortisnisi.com': 93},
#   4: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 91,
#    'orci.quis@dignissim.ca': 89,
#    'dui@enim.ca': 92,
#    'eu@Craseget.com': 93,
#    'aliquet.vel@Vestibulum.org': 83,
#    'at@massa.net': 89,
#    'in@iaculis.org': 90,
#    'porttitor.eros@ametdapibus.com': 99,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 73,
#    'Curabitur.egestas.nunc@erat.org': 90,
#    'ante.ipsum@Phasellusat.edu': 65,
#    'faucibus@elitNulla.edu': 91,
#    'Nunc.ullamcorper@aceleifend.net': 90,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 98,
#    'turpis@milorem.ca': 90,
#    'semper.auctor.Mauris@Maurismagna.com': 95,
#    'blandit@augue.ca': 93,
#    'tellus.imperdiet@necmetus.net': 95,
#    'dui.quis@pretiumneque.com': 73,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 81,
#    'sit@duiSuspendisse.edu': 88,
#    'pede.Nunc.sed@justoProin.co.uk': 90,
#    'eu.ultrices.sit@tempuseu.ca': 90,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 95,
#    'ut.nulla@Aliquam.edu': 100,
#    'sem.Nulla@lacuspedesagittis.co.uk': 87,
#    'Integer.tincidunt.aliquam@enim.ca': 86,
#    'convallis.convallis@facilisi.edu': 70,
#    'Etiam.laoreet.libero@amet.org': 91,
#    'pede@pharetrasedhendrerit.co.uk': 87,
#    'congue.a@eudoloregestas.edu': 98,
#    'gravida.Aliquam.tincidunt@nulla.ca': 85,
#    'vitae@Pellentesque.com': 87,
#    'inceptos@semperet.ca': 90,
#    'nec.cursus@arcuVestibulumante.net': 70,
#    'mauris.Morbi@aliquetnec.edu': 94,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 85,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 78,
#    'Nulla@atauctorullamcorper.com': 88,
#    'Nunc.laoreet@Aliquamrutrum.ca': 81,
#    'a@acarcuNunc.org': 84,
#    'Phasellus.fermentum@Proin.org': 85,
#    'dui.in.sodales@lorem.org': 69,
#    'nisl.Maecenas@justo.com': 94,
#    'volutpat@quis.com': 92,
#    'vitae.orci.Phasellus@turpis.com': 70,
#    'odio@nonmassa.net': 91,
#    'Phasellus.at.augue@eu.co.uk': 23,
#    'vel@enimnonnisi.com': 78,
#    'orci@purusDuiselementum.ca': 97,
#    'Pellentesque@eros.ca': 95,
#    'Mauris.non.dui@blanditatnisi.edu': 35,
#    'Fusce@vitae.ca': 82,
#    'malesuada.Integer@ornareplacerat.com': 98,
#    'id.ante@tellus.net': 73,
#    'sem.Nulla@at.edu': 76,
#    'ut.nulla.Cras@nisi.org': 92,
#    'enim.diam.vel@fringillamilacinia.co.uk': 88,
#    'et.commodo@elit.com': 88,
#    'nulla.Integer.urna@tortor.ca': 87,
#    'velit.Quisque@scelerisque.co.uk': 92,
#    'aliquet.sem@non.co.uk': 87,
#    'odio.Aliquam@rhoncus.ca': 92,
#    'non@Proinmi.edu': 80,
#    'lorem.fringilla.ornare@non.com': 69,
#    'ante@auctorMauris.edu': 89,
#    'ullamcorper.Duis.at@netus.org': 86,
#    'non.massa.non@Morbivehicula.org': 98,
#    'Maecenas.mi@Etiamvestibulum.ca': 93,
#    'Quisque.porttitor.eros@enimMauris.ca': 99,
#    'consequat.purus.Maecenas@eratSed.com': 99,
#    'mi@felis.edu': 87,
#    'orci@metus.edu': 9,
#    'aliquet.libero.Integer@lectussit.net': 61,
#    'vel@id.ca': 91,
#    'ipsum.sodales@purusmauris.edu': 87,
#    'ac@cubiliaCuraePhasellus.org': 87,
#    'Donec.dignissim@luctus.ca': 82,
#    'libero@sagittislobortismauris.net': 99,
#    'sed@quamquisdiam.edu': 22,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 99,
#    'Proin@vitae.net': 95,
#    'magna.Sed.eu@loremlorem.ca': 86,
#    'Quisque@sitametnulla.co.uk': 79,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 29,
#    'Nunc.laoreet@adlitora.net': 95,
#    'magnis.dis@fringillapurus.org': 81,
#    'quis@Suspendisse.net': 100,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 5,
#    'aliquet.metus.urna@interdum.edu': 42,
#    'sem.semper.erat@mattissemper.net': 89,
#    'Fusce@risus.co.uk': 97,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 80,
#    'erat@auguemalesuada.net': 96,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 97,
#    'et@turpisegestasAliquam.org': 100,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 98,
#    'adipiscing.elit@eutellusPhasellus.edu': 98,
#    'cursus.a@feugiattelluslorem.edu': 62,
#    'adipiscing@lobortisnisi.com': 94},
#   5: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 87,
#    'orci.quis@dignissim.ca': 74,
#    'dui@enim.ca': 5,
#    'eu@Craseget.com': 85,
#    'aliquet.vel@Vestibulum.org': 26,
#    'at@massa.net': 90,
#    'in@iaculis.org': 87,
#    'porttitor.eros@ametdapibus.com': 74,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 89,
#    'Curabitur.egestas.nunc@erat.org': 94,
#    'ante.ipsum@Phasellusat.edu': 100,
#    'faucibus@elitNulla.edu': 73,
#    'Nunc.ullamcorper@aceleifend.net': 99,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 86,
#    'turpis@milorem.ca': 92,
#    'semper.auctor.Mauris@Maurismagna.com': 82,
#    'blandit@augue.ca': 77,
#    'tellus.imperdiet@necmetus.net': 87,
#    'dui.quis@pretiumneque.com': 82,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 76,
#    'sit@duiSuspendisse.edu': 90,
#    'pede.Nunc.sed@justoProin.co.uk': 69,
#    'eu.ultrices.sit@tempuseu.ca': 56,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 89,
#    'ut.nulla@Aliquam.edu': 64,
#    'sem.Nulla@lacuspedesagittis.co.uk': 91,
#    'Integer.tincidunt.aliquam@enim.ca': 98,
#    'convallis.convallis@facilisi.edu': 83,
#    'Etiam.laoreet.libero@amet.org': 82,
#    'pede@pharetrasedhendrerit.co.uk': 98,
#    'congue.a@eudoloregestas.edu': 98,
#    'gravida.Aliquam.tincidunt@nulla.ca': 91,
#    'vitae@Pellentesque.com': 97,
#    'inceptos@semperet.ca': 93,
#    'nec.cursus@arcuVestibulumante.net': 95,
#    'mauris.Morbi@aliquetnec.edu': 47,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 99,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 89,
#    'Nulla@atauctorullamcorper.com': 86,
#    'Nunc.laoreet@Aliquamrutrum.ca': 81,
#    'a@acarcuNunc.org': 86,
#    'Phasellus.fermentum@Proin.org': 64,
#    'dui.in.sodales@lorem.org': 98,
#    'nisl.Maecenas@justo.com': 82,
#    'volutpat@quis.com': 82,
#    'vitae.orci.Phasellus@turpis.com': 5,
#    'odio@nonmassa.net': 96,
#    'Phasellus.at.augue@eu.co.uk': 90,
#    'vel@enimnonnisi.com': 84,
#    'orci@purusDuiselementum.ca': 97,
#    'Pellentesque@eros.ca': 98,
#    'Mauris.non.dui@blanditatnisi.edu': 97,
#    'Fusce@vitae.ca': 85,
#    'malesuada.Integer@ornareplacerat.com': 99,
#    'id.ante@tellus.net': 95,
#    'sem.Nulla@at.edu': 64,
#    'ut.nulla.Cras@nisi.org': 96,
#    'enim.diam.vel@fringillamilacinia.co.uk': 91,
#    'et.commodo@elit.com': 90,
#    'nulla.Integer.urna@tortor.ca': 5,
#    'velit.Quisque@scelerisque.co.uk': 89,
#    'aliquet.sem@non.co.uk': 92,
#    'odio.Aliquam@rhoncus.ca': 98,
#    'non@Proinmi.edu': 100,
#    'lorem.fringilla.ornare@non.com': 86,
#    'ante@auctorMauris.edu': 26,
#    'ullamcorper.Duis.at@netus.org': 87,
#    'non.massa.non@Morbivehicula.org': 92,
#    'Maecenas.mi@Etiamvestibulum.ca': 63,
#    'Quisque.porttitor.eros@enimMauris.ca': 96,
#    'consequat.purus.Maecenas@eratSed.com': 80,
#    'mi@felis.edu': 97,
#    'orci@metus.edu': 71,
#    'aliquet.libero.Integer@lectussit.net': 81,
#    'vel@id.ca': 72,
#    'ipsum.sodales@purusmauris.edu': 62,
#    'ac@cubiliaCuraePhasellus.org': 95,
#    'Donec.dignissim@luctus.ca': 82,
#    'libero@sagittislobortismauris.net': 99,
#    'sed@quamquisdiam.edu': 91,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 95,
#    'Proin@vitae.net': 99,
#    'magna.Sed.eu@loremlorem.ca': 91,
#    'Quisque@sitametnulla.co.uk': 92,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 75,
#    'Nunc.laoreet@adlitora.net': 96,
#    'magnis.dis@fringillapurus.org': 96,
#    'quis@Suspendisse.net': 80,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 90,
#    'aliquet.metus.urna@interdum.edu': 96,
#    'sem.semper.erat@mattissemper.net': 80,
#    'Fusce@risus.co.uk': 89,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 94,
#    'erat@auguemalesuada.net': 91,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 93,
#    'et@turpisegestasAliquam.org': 82,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 91,
#    'adipiscing.elit@eutellusPhasellus.edu': 99,
#    'cursus.a@feugiattelluslorem.edu': 99,
#    'adipiscing@lobortisnisi.com': 85},
#   6: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 83,
#    'orci.quis@dignissim.ca': 96,
#    'dui@enim.ca': 81,
#    'eu@Craseget.com': 99,
#    'aliquet.vel@Vestibulum.org': 80,
#    'at@massa.net': 70,
#    'in@iaculis.org': 94,
#    'porttitor.eros@ametdapibus.com': 64,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 92,
#    'Curabitur.egestas.nunc@erat.org': 92,
#    'ante.ipsum@Phasellusat.edu': 95,
#    'faucibus@elitNulla.edu': 92,
#    'Nunc.ullamcorper@aceleifend.net': 98,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 75,
#    'turpis@milorem.ca': 63,
#    'semper.auctor.Mauris@Maurismagna.com': 93,
#    'blandit@augue.ca': 78,
#    'tellus.imperdiet@necmetus.net': 95,
#    'dui.quis@pretiumneque.com': 74,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 95,
#    'sit@duiSuspendisse.edu': 68,
#    'pede.Nunc.sed@justoProin.co.uk': 98,
#    'eu.ultrices.sit@tempuseu.ca': 59,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 92,
#    'ut.nulla@Aliquam.edu': 94,
#    'sem.Nulla@lacuspedesagittis.co.uk': 88,
#    'Integer.tincidunt.aliquam@enim.ca': 84,
#    'convallis.convallis@facilisi.edu': 96,
#    'Etiam.laoreet.libero@amet.org': 100,
#    'pede@pharetrasedhendrerit.co.uk': 95,
#    'congue.a@eudoloregestas.edu': 83,
#    'gravida.Aliquam.tincidunt@nulla.ca': 88,
#    'vitae@Pellentesque.com': 95,
#    'inceptos@semperet.ca': 82,
#    'nec.cursus@arcuVestibulumante.net': 72,
#    'mauris.Morbi@aliquetnec.edu': 97,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 90,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 90,
#    'Nulla@atauctorullamcorper.com': 92,
#    'Nunc.laoreet@Aliquamrutrum.ca': 62,
#    'a@acarcuNunc.org': 89,
#    'Phasellus.fermentum@Proin.org': 60,
#    'dui.in.sodales@lorem.org': 89,
#    'nisl.Maecenas@justo.com': 89,
#    'volutpat@quis.com': 90,
#    'vitae.orci.Phasellus@turpis.com': 98,
#    'odio@nonmassa.net': 98,
#    'Phasellus.at.augue@eu.co.uk': 90,
#    'vel@enimnonnisi.com': 91,
#    'orci@purusDuiselementum.ca': 98,
#    'Pellentesque@eros.ca': 89,
#    'Mauris.non.dui@blanditatnisi.edu': 100,
#    'Fusce@vitae.ca': 100,
#    'malesuada.Integer@ornareplacerat.com': 72,
#    'id.ante@tellus.net': 95,
#    'sem.Nulla@at.edu': 96,
#    'ut.nulla.Cras@nisi.org': 98,
#    'enim.diam.vel@fringillamilacinia.co.uk': 70,
#    'et.commodo@elit.com': 99,
#    'nulla.Integer.urna@tortor.ca': 90,
#    'velit.Quisque@scelerisque.co.uk': 72,
#    'aliquet.sem@non.co.uk': 60,
#    'odio.Aliquam@rhoncus.ca': 99,
#    'non@Proinmi.edu': 90,
#    'lorem.fringilla.ornare@non.com': 84,
#    'ante@auctorMauris.edu': 81,
#    'ullamcorper.Duis.at@netus.org': 96,
#    'non.massa.non@Morbivehicula.org': 97,
#    'Maecenas.mi@Etiamvestibulum.ca': 86,
#    'Quisque.porttitor.eros@enimMauris.ca': 93,
#    'consequat.purus.Maecenas@eratSed.com': 95,
#    'mi@felis.edu': 98,
#    'orci@metus.edu': 94,
#    'aliquet.libero.Integer@lectussit.net': 90,
#    'vel@id.ca': 100,
#    'ipsum.sodales@purusmauris.edu': 70,
#    'ac@cubiliaCuraePhasellus.org': 76,
#    'Donec.dignissim@luctus.ca': 87,
#    'libero@sagittislobortismauris.net': 92,
#    'sed@quamquisdiam.edu': 92,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 92,
#    'Proin@vitae.net': 100,
#    'magna.Sed.eu@loremlorem.ca': 90,
#    'Quisque@sitametnulla.co.uk': 89,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 89,
#    'Nunc.laoreet@adlitora.net': 85,
#    'magnis.dis@fringillapurus.org': 91,
#    'quis@Suspendisse.net': 81,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 99,
#    'aliquet.metus.urna@interdum.edu': 92,
#    'sem.semper.erat@mattissemper.net': 98,
#    'Fusce@risus.co.uk': 99,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 89,
#    'erat@auguemalesuada.net': 21,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 61,
#    'et@turpisegestasAliquam.org': 88,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 82,
#    'adipiscing.elit@eutellusPhasellus.edu': 91,
#    'cursus.a@feugiattelluslorem.edu': 93,
#    'adipiscing@lobortisnisi.com': 96},
#   7: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 81,
#    'orci.quis@dignissim.ca': 92,
#    'dui@enim.ca': 94,
#    'eu@Craseget.com': 99,
#    'aliquet.vel@Vestibulum.org': 77,
#    'at@massa.net': 90,
#    'in@iaculis.org': 18,
#    'porttitor.eros@ametdapibus.com': 73,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 93,
#    'Curabitur.egestas.nunc@erat.org': 85,
#    'ante.ipsum@Phasellusat.edu': 91,
#    'faucibus@elitNulla.edu': 65,
#    'Nunc.ullamcorper@aceleifend.net': 98,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 85,
#    'turpis@milorem.ca': 71,
#    'semper.auctor.Mauris@Maurismagna.com': 77,
#    'blandit@augue.ca': 97,
#    'tellus.imperdiet@necmetus.net': 86,
#    'dui.quis@pretiumneque.com': 91,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 99,
#    'sit@duiSuspendisse.edu': 67,
#    'pede.Nunc.sed@justoProin.co.uk': 42,
#    'eu.ultrices.sit@tempuseu.ca': 78,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 80,
#    'ut.nulla@Aliquam.edu': 87,
#    'sem.Nulla@lacuspedesagittis.co.uk': 82,
#    'Integer.tincidunt.aliquam@enim.ca': 98,
#    'convallis.convallis@facilisi.edu': 97,
#    'Etiam.laoreet.libero@amet.org': 94,
#    'pede@pharetrasedhendrerit.co.uk': 96,
#    'congue.a@eudoloregestas.edu': 88,
#    'gravida.Aliquam.tincidunt@nulla.ca': 98,
#    'vitae@Pellentesque.com': 85,
#    'inceptos@semperet.ca': 82,
#    'nec.cursus@arcuVestibulumante.net': 91,
#    'mauris.Morbi@aliquetnec.edu': 94,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 87,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 3,
#    'Nulla@atauctorullamcorper.com': 79,
#    'Nunc.laoreet@Aliquamrutrum.ca': 88,
#    'a@acarcuNunc.org': 87,
#    'Phasellus.fermentum@Proin.org': 91,
#    'dui.in.sodales@lorem.org': 98,
#    'nisl.Maecenas@justo.com': 96,
#    'volutpat@quis.com': 15,
#    'vitae.orci.Phasellus@turpis.com': 97,
#    'odio@nonmassa.net': 96,
#    'Phasellus.at.augue@eu.co.uk': 87,
#    'vel@enimnonnisi.com': 95,
#    'orci@purusDuiselementum.ca': 80,
#    'Pellentesque@eros.ca': 82,
#    'Mauris.non.dui@blanditatnisi.edu': 85,
#    'Fusce@vitae.ca': 77,
#    'malesuada.Integer@ornareplacerat.com': 82,
#    'id.ante@tellus.net': 86,
#    'sem.Nulla@at.edu': 64,
#    'ut.nulla.Cras@nisi.org': 83,
#    'enim.diam.vel@fringillamilacinia.co.uk': 75,
#    'et.commodo@elit.com': 98,
#    'nulla.Integer.urna@tortor.ca': 71,
#    'velit.Quisque@scelerisque.co.uk': 75,
#    'aliquet.sem@non.co.uk': 98,
#    'odio.Aliquam@rhoncus.ca': 96,
#    'non@Proinmi.edu': 93,
#    'lorem.fringilla.ornare@non.com': 81,
#    'ante@auctorMauris.edu': 82,
#    'ullamcorper.Duis.at@netus.org': 92,
#    'non.massa.non@Morbivehicula.org': 90,
#    'Maecenas.mi@Etiamvestibulum.ca': 68,
#    'Quisque.porttitor.eros@enimMauris.ca': 70,
#    'consequat.purus.Maecenas@eratSed.com': 85,
#    'mi@felis.edu': 15,
#    'orci@metus.edu': 87,
#    'aliquet.libero.Integer@lectussit.net': 91,
#    'vel@id.ca': 89,
#    'ipsum.sodales@purusmauris.edu': 96,
#    'ac@cubiliaCuraePhasellus.org': 97,
#    'Donec.dignissim@luctus.ca': 85,
#    'libero@sagittislobortismauris.net': 87,
#    'sed@quamquisdiam.edu': 98,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 96,
#    'Proin@vitae.net': 99,
#    'magna.Sed.eu@loremlorem.ca': 84,
#    'Quisque@sitametnulla.co.uk': 93,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 100,
#    'Nunc.laoreet@adlitora.net': 77,
#    'magnis.dis@fringillapurus.org': 85,
#    'quis@Suspendisse.net': 85,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 86,
#    'aliquet.metus.urna@interdum.edu': 90,
#    'sem.semper.erat@mattissemper.net': 68,
#    'Fusce@risus.co.uk': 81,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 99,
#    'erat@auguemalesuada.net': 85,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 95,
#    'et@turpisegestasAliquam.org': 97,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 78,
#    'adipiscing.elit@eutellusPhasellus.edu': 95,
#    'cursus.a@feugiattelluslorem.edu': 98,
#    'adipiscing@lobortisnisi.com': 81},
#   8: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 89,
#    'orci.quis@dignissim.ca': 95,
#    'dui@enim.ca': 97,
#    'eu@Craseget.com': 53,
#    'aliquet.vel@Vestibulum.org': 96,
#    'at@massa.net': 60,
#    'in@iaculis.org': 100,
#    'porttitor.eros@ametdapibus.com': 73,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 92,
#    'Curabitur.egestas.nunc@erat.org': 97,
#    'ante.ipsum@Phasellusat.edu': 92,
#    'faucibus@elitNulla.edu': 94,
#    'Nunc.ullamcorper@aceleifend.net': 70,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 98,
#    'turpis@milorem.ca': 91,
#    'semper.auctor.Mauris@Maurismagna.com': 8,
#    'blandit@augue.ca': 98,
#    'tellus.imperdiet@necmetus.net': 81,
#    'dui.quis@pretiumneque.com': 62,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 90,
#    'sit@duiSuspendisse.edu': 71,
#    'pede.Nunc.sed@justoProin.co.uk': 97,
#    'eu.ultrices.sit@tempuseu.ca': 88,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 85,
#    'ut.nulla@Aliquam.edu': 71,
#    'sem.Nulla@lacuspedesagittis.co.uk': 81,
#    'Integer.tincidunt.aliquam@enim.ca': 96,
#    'convallis.convallis@facilisi.edu': 98,
#    'Etiam.laoreet.libero@amet.org': 69,
#    'pede@pharetrasedhendrerit.co.uk': 90,
#    'congue.a@eudoloregestas.edu': 89,
#    'gravida.Aliquam.tincidunt@nulla.ca': 87,
#    'vitae@Pellentesque.com': 84,
#    'inceptos@semperet.ca': 62,
#    'nec.cursus@arcuVestibulumante.net': 98,
#    'mauris.Morbi@aliquetnec.edu': 96,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 95,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 87,
#    'Nulla@atauctorullamcorper.com': 94,
#    'Nunc.laoreet@Aliquamrutrum.ca': 86,
#    'a@acarcuNunc.org': 91,
#    'Phasellus.fermentum@Proin.org': 63,
#    'dui.in.sodales@lorem.org': 91,
#    'nisl.Maecenas@justo.com': 80,
#    'volutpat@quis.com': 68,
#    'vitae.orci.Phasellus@turpis.com': 100,
#    'odio@nonmassa.net': 97,
#    'Phasellus.at.augue@eu.co.uk': 86,
#    'vel@enimnonnisi.com': 85,
#    'orci@purusDuiselementum.ca': 22,
#    'Pellentesque@eros.ca': 71,
#    'Mauris.non.dui@blanditatnisi.edu': 79,
#    'Fusce@vitae.ca': 80,
#    'malesuada.Integer@ornareplacerat.com': 60,
#    'id.ante@tellus.net': 83,
#    'sem.Nulla@at.edu': 75,
#    'ut.nulla.Cras@nisi.org': 95,
#    'enim.diam.vel@fringillamilacinia.co.uk': 99,
#    'et.commodo@elit.com': 9,
#    'nulla.Integer.urna@tortor.ca': 99,
#    'velit.Quisque@scelerisque.co.uk': 91,
#    'aliquet.sem@non.co.uk': 81,
#    'odio.Aliquam@rhoncus.ca': 80,
#    'non@Proinmi.edu': 99,
#    'lorem.fringilla.ornare@non.com': 96,
#    'ante@auctorMauris.edu': 97,
#    'ullamcorper.Duis.at@netus.org': 90,
#    'non.massa.non@Morbivehicula.org': 61,
#    'Maecenas.mi@Etiamvestibulum.ca': 80,
#    'Quisque.porttitor.eros@enimMauris.ca': 94,
#    'consequat.purus.Maecenas@eratSed.com': 96,
#    'mi@felis.edu': 94,
#    'orci@metus.edu': 94,
#    'aliquet.libero.Integer@lectussit.net': 75,
#    'vel@id.ca': 92,
#    'ipsum.sodales@purusmauris.edu': 91,
#    'ac@cubiliaCuraePhasellus.org': 99,
#    'Donec.dignissim@luctus.ca': 99,
#    'libero@sagittislobortismauris.net': 80,
#    'sed@quamquisdiam.edu': 81,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 87,
#    'Proin@vitae.net': 97,
#    'magna.Sed.eu@loremlorem.ca': 60,
#    'Quisque@sitametnulla.co.uk': 92,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 96,
#    'Nunc.laoreet@adlitora.net': 46,
#    'magnis.dis@fringillapurus.org': 92,
#    'quis@Suspendisse.net': 77,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 93,
#    'aliquet.metus.urna@interdum.edu': 89,
#    'sem.semper.erat@mattissemper.net': 69,
#    'Fusce@risus.co.uk': 80,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 87,
#    'erat@auguemalesuada.net': 91,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 73,
#    'et@turpisegestasAliquam.org': 85,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 75,
#    'adipiscing.elit@eutellusPhasellus.edu': 100,
#    'cursus.a@feugiattelluslorem.edu': 93,
#    'adipiscing@lobortisnisi.com': 91},
#   9: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 93,
#    'orci.quis@dignissim.ca': 95,
#    'dui@enim.ca': 72,
#    'eu@Craseget.com': 82,
#    'aliquet.vel@Vestibulum.org': 96,
#    'at@massa.net': 94,
#    'in@iaculis.org': 74,
#    'porttitor.eros@ametdapibus.com': 93,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 90,
#    'Curabitur.egestas.nunc@erat.org': 96,
#    'ante.ipsum@Phasellusat.edu': 84,
#    'faucibus@elitNulla.edu': 98,
#    'Nunc.ullamcorper@aceleifend.net': 89,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 96,
#    'turpis@milorem.ca': 88,
#    'semper.auctor.Mauris@Maurismagna.com': 91,
#    'blandit@augue.ca': 70,
#    'tellus.imperdiet@necmetus.net': 77,
#    'dui.quis@pretiumneque.com': 85,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 90,
#    'sit@duiSuspendisse.edu': 85,
#    'pede.Nunc.sed@justoProin.co.uk': 73,
#    'eu.ultrices.sit@tempuseu.ca': 96,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 97,
#    'ut.nulla@Aliquam.edu': 92,
#    'sem.Nulla@lacuspedesagittis.co.uk': 86,
#    'Integer.tincidunt.aliquam@enim.ca': 95,
#    'convallis.convallis@facilisi.edu': 86,
#    'Etiam.laoreet.libero@amet.org': 99,
#    'pede@pharetrasedhendrerit.co.uk': 80,
#    'congue.a@eudoloregestas.edu': 88,
#    'gravida.Aliquam.tincidunt@nulla.ca': 93,
#    'vitae@Pellentesque.com': 80,
#    'inceptos@semperet.ca': 93,
#    'nec.cursus@arcuVestibulumante.net': 89,
#    'mauris.Morbi@aliquetnec.edu': 99,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 94,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 99,
#    'Nulla@atauctorullamcorper.com': 92,
#    'Nunc.laoreet@Aliquamrutrum.ca': 97,
#    'a@acarcuNunc.org': 82,
#    'Phasellus.fermentum@Proin.org': 74,
#    'dui.in.sodales@lorem.org': 94,
#    'nisl.Maecenas@justo.com': 21,
#    'volutpat@quis.com': 73,
#    'vitae.orci.Phasellus@turpis.com': 22,
#    'odio@nonmassa.net': 80,
#    'Phasellus.at.augue@eu.co.uk': 93,
#    'vel@enimnonnisi.com': 70,
#    'orci@purusDuiselementum.ca': 90,
#    'Pellentesque@eros.ca': 99,
#    'Mauris.non.dui@blanditatnisi.edu': 83,
#    'Fusce@vitae.ca': 60,
#    'malesuada.Integer@ornareplacerat.com': 92,
#    'id.ante@tellus.net': 92,
#    'sem.Nulla@at.edu': 81,
#    'ut.nulla.Cras@nisi.org': 82,
#    'enim.diam.vel@fringillamilacinia.co.uk': 91,
#    'et.commodo@elit.com': 95,
#    'nulla.Integer.urna@tortor.ca': 95,
#    'velit.Quisque@scelerisque.co.uk': 89,
#    'aliquet.sem@non.co.uk': 88,
#    'odio.Aliquam@rhoncus.ca': 96,
#    'non@Proinmi.edu': 89,
#    'lorem.fringilla.ornare@non.com': 72,
#    'ante@auctorMauris.edu': 78,
#    'ullamcorper.Duis.at@netus.org': 99,
#    'non.massa.non@Morbivehicula.org': 94,
#    'Maecenas.mi@Etiamvestibulum.ca': 87,
#    'Quisque.porttitor.eros@enimMauris.ca': 70,
#    'consequat.purus.Maecenas@eratSed.com': 93,
#    'mi@felis.edu': 93,
#    'orci@metus.edu': 85,
#    'aliquet.libero.Integer@lectussit.net': 96,
#    'vel@id.ca': 98,
#    'ipsum.sodales@purusmauris.edu': 85,
#    'ac@cubiliaCuraePhasellus.org': 90,
#    'Donec.dignissim@luctus.ca': 83,
#    'libero@sagittislobortismauris.net': 97,
#    'sed@quamquisdiam.edu': 88,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 88,
#    'Proin@vitae.net': 74,
#    'magna.Sed.eu@loremlorem.ca': 97,
#    'Quisque@sitametnulla.co.uk': 85,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 95,
#    'Nunc.laoreet@adlitora.net': 86,
#    'magnis.dis@fringillapurus.org': 85,
#    'quis@Suspendisse.net': 76,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 98,
#    'aliquet.metus.urna@interdum.edu': 60,
#    'sem.semper.erat@mattissemper.net': 84,
#    'Fusce@risus.co.uk': 96,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 97,
#    'erat@auguemalesuada.net': 72,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 86,
#    'et@turpisegestasAliquam.org': 100,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 94,
#    'adipiscing.elit@eutellusPhasellus.edu': 86,
#    'cursus.a@feugiattelluslorem.edu': 69,
#    'adipiscing@lobortisnisi.com': 87}},
#  'quizzes': {1: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 94,
#    'orci.quis@dignissim.ca': 82,
#    'dui@enim.ca': 95,
#    'eu@Craseget.com': 98,
#    'aliquet.vel@Vestibulum.org': 83,
#    'at@massa.net': 92,
#    'in@iaculis.org': 85,
#    'porttitor.eros@ametdapibus.com': 93,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 68,
#    'Curabitur.egestas.nunc@erat.org': 84,
#    'ante.ipsum@Phasellusat.edu': 94,
#    'faucibus@elitNulla.edu': 100,
#    'Nunc.ullamcorper@aceleifend.net': 82,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 72,
#    'turpis@milorem.ca': 94,
#    'semper.auctor.Mauris@Maurismagna.com': 76,
#    'blandit@augue.ca': 92,
#    'tellus.imperdiet@necmetus.net': 98,
#    'dui.quis@pretiumneque.com': 85,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 61,
#    'sit@duiSuspendisse.edu': 82,
#    'pede.Nunc.sed@justoProin.co.uk': 82,
#    'eu.ultrices.sit@tempuseu.ca': 86,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 49,
#    'ut.nulla@Aliquam.edu': 84,
#    'sem.Nulla@lacuspedesagittis.co.uk': 99,
#    'Integer.tincidunt.aliquam@enim.ca': 91,
#    'convallis.convallis@facilisi.edu': 68,
#    'Etiam.laoreet.libero@amet.org': 73,
#    'pede@pharetrasedhendrerit.co.uk': 95,
#    'congue.a@eudoloregestas.edu': 95,
#    'gravida.Aliquam.tincidunt@nulla.ca': 95,
#    'vitae@Pellentesque.com': 8,
#    'inceptos@semperet.ca': 82,
#    'nec.cursus@arcuVestibulumante.net': 94,
#    'mauris.Morbi@aliquetnec.edu': 68,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 89,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 70,
#    'Nulla@atauctorullamcorper.com': 97,
#    'Nunc.laoreet@Aliquamrutrum.ca': 28,
#    'a@acarcuNunc.org': 92,
#    'Phasellus.fermentum@Proin.org': 80,
#    'dui.in.sodales@lorem.org': 95,
#    'nisl.Maecenas@justo.com': 99,
#    'volutpat@quis.com': 86,
#    'vitae.orci.Phasellus@turpis.com': 94,
#    'odio@nonmassa.net': 89,
#    'Phasellus.at.augue@eu.co.uk': 37,
#    'vel@enimnonnisi.com': 64,
#    'orci@purusDuiselementum.ca': 39,
#    'Pellentesque@eros.ca': 25,
#    'Mauris.non.dui@blanditatnisi.edu': 94,
#    'Fusce@vitae.ca': 78,
#    'malesuada.Integer@ornareplacerat.com': 85,
#    'id.ante@tellus.net': 18,
#    'sem.Nulla@at.edu': 85,
#    'ut.nulla.Cras@nisi.org': 90,
#    'enim.diam.vel@fringillamilacinia.co.uk': 88,
#    'et.commodo@elit.com': 94,
#    'nulla.Integer.urna@tortor.ca': 96,
#    'velit.Quisque@scelerisque.co.uk': 99,
#    'aliquet.sem@non.co.uk': 99,
#    'odio.Aliquam@rhoncus.ca': 34,
#    'non@Proinmi.edu': 95,
#    'lorem.fringilla.ornare@non.com': 95,
#    'ante@auctorMauris.edu': 74,
#    'ullamcorper.Duis.at@netus.org': 76,
#    'non.massa.non@Morbivehicula.org': 98,
#    'Maecenas.mi@Etiamvestibulum.ca': 99,
#    'Quisque.porttitor.eros@enimMauris.ca': 92,
#    'consequat.purus.Maecenas@eratSed.com': 99,
#    'mi@felis.edu': 91,
#    'orci@metus.edu': 96,
#    'aliquet.libero.Integer@lectussit.net': 97,
#    'vel@id.ca': 98,
#    'ipsum.sodales@purusmauris.edu': 86,
#    'ac@cubiliaCuraePhasellus.org': 90,
#    'Donec.dignissim@luctus.ca': 96,
#    'libero@sagittislobortismauris.net': 9,
#    'sed@quamquisdiam.edu': 66,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 65,
#    'Proin@vitae.net': 74,
#    'magna.Sed.eu@loremlorem.ca': 95,
#    'Quisque@sitametnulla.co.uk': 93,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 92,
#    'Nunc.laoreet@adlitora.net': 92,
#    'magnis.dis@fringillapurus.org': 86,
#    'quis@Suspendisse.net': 35,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 77,
#    'aliquet.metus.urna@interdum.edu': 82,
#    'sem.semper.erat@mattissemper.net': 99,
#    'Fusce@risus.co.uk': 88,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 65,
#    'erat@auguemalesuada.net': 71,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 98,
#    'et@turpisegestasAliquam.org': 60,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 99,
#    'adipiscing.elit@eutellusPhasellus.edu': 49,
#    'cursus.a@feugiattelluslorem.edu': 10,
#    'adipiscing@lobortisnisi.com': 65},
#   2: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 90,
#    'orci.quis@dignissim.ca': 93,
#    'dui@enim.ca': 72,
#    'eu@Craseget.com': 74,
#    'aliquet.vel@Vestibulum.org': 75,
#    'at@massa.net': 83,
#    'in@iaculis.org': 90,
#    'porttitor.eros@ametdapibus.com': 86,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 0,
#    'Curabitur.egestas.nunc@erat.org': 87,
#    'ante.ipsum@Phasellusat.edu': 63,
#    'faucibus@elitNulla.edu': 91,
#    'Nunc.ullamcorper@aceleifend.net': 100,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 92,
#    'turpis@milorem.ca': 80,
#    'semper.auctor.Mauris@Maurismagna.com': 86,
#    'blandit@augue.ca': 92,
#    'tellus.imperdiet@necmetus.net': 96,
#    'dui.quis@pretiumneque.com': 92,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 98,
#    'sit@duiSuspendisse.edu': 97,
#    'pede.Nunc.sed@justoProin.co.uk': 0,
#    'eu.ultrices.sit@tempuseu.ca': 88,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 90,
#    'ut.nulla@Aliquam.edu': 70,
#    'sem.Nulla@lacuspedesagittis.co.uk': 80,
#    'Integer.tincidunt.aliquam@enim.ca': 61,
#    'convallis.convallis@facilisi.edu': 73,
#    'Etiam.laoreet.libero@amet.org': 100,
#    'pede@pharetrasedhendrerit.co.uk': 85,
#    'congue.a@eudoloregestas.edu': 91,
#    'gravida.Aliquam.tincidunt@nulla.ca': 82,
#    'vitae@Pellentesque.com': 28,
#    'inceptos@semperet.ca': 94,
#    'nec.cursus@arcuVestibulumante.net': 70,
#    'mauris.Morbi@aliquetnec.edu': 90,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 85,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 98,
#    'Nulla@atauctorullamcorper.com': 16,
#    'Nunc.laoreet@Aliquamrutrum.ca': 61,
#    'a@acarcuNunc.org': 100,
#    'Phasellus.fermentum@Proin.org': 99,
#    'dui.in.sodales@lorem.org': 88,
#    'nisl.Maecenas@justo.com': 82,
#    'volutpat@quis.com': 78,
#    'vitae.orci.Phasellus@turpis.com': 89,
#    'odio@nonmassa.net': 100,
#    'Phasellus.at.augue@eu.co.uk': 96,
#    'vel@enimnonnisi.com': 84,
#    'orci@purusDuiselementum.ca': 92,
#    'Pellentesque@eros.ca': 50,
#    'Mauris.non.dui@blanditatnisi.edu': 89,
#    'Fusce@vitae.ca': 75,
#    'malesuada.Integer@ornareplacerat.com': 93,
#    'id.ante@tellus.net': 90,
#    'sem.Nulla@at.edu': 76,
#    'ut.nulla.Cras@nisi.org': 88,
#    'enim.diam.vel@fringillamilacinia.co.uk': 82,
#    'et.commodo@elit.com': 81,
#    'nulla.Integer.urna@tortor.ca': 88,
#    'velit.Quisque@scelerisque.co.uk': 97,
#    'aliquet.sem@non.co.uk': 61,
#    'odio.Aliquam@rhoncus.ca': 83,
#    'non@Proinmi.edu': 84,
#    'lorem.fringilla.ornare@non.com': 93,
#    'ante@auctorMauris.edu': 80,
#    'ullamcorper.Duis.at@netus.org': 69,
#    'non.massa.non@Morbivehicula.org': 93,
#    'Maecenas.mi@Etiamvestibulum.ca': 93,
#    'Quisque.porttitor.eros@enimMauris.ca': 100,
#    'consequat.purus.Maecenas@eratSed.com': 79,
#    'mi@felis.edu': 93,
#    'orci@metus.edu': 84,
#    'aliquet.libero.Integer@lectussit.net': 74,
#    'vel@id.ca': 91,
#    'ipsum.sodales@purusmauris.edu': 81,
#    'ac@cubiliaCuraePhasellus.org': 89,
#    'Donec.dignissim@luctus.ca': 94,
#    'libero@sagittislobortismauris.net': 82,
#    'sed@quamquisdiam.edu': 99,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 52,
#    'Proin@vitae.net': 82,
#    'magna.Sed.eu@loremlorem.ca': 91,
#    'Quisque@sitametnulla.co.uk': 87,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 90,
#    'Nunc.laoreet@adlitora.net': 76,
#    'magnis.dis@fringillapurus.org': 90,
#    'quis@Suspendisse.net': 92,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 58,
#    'aliquet.metus.urna@interdum.edu': 13,
#    'sem.semper.erat@mattissemper.net': 98,
#    'Fusce@risus.co.uk': 90,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 100,
#    'erat@auguemalesuada.net': 48,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 80,
#    'et@turpisegestasAliquam.org': 93,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 94,
#    'adipiscing.elit@eutellusPhasellus.edu': 97,
#    'cursus.a@feugiattelluslorem.edu': 99,
#    'adipiscing@lobortisnisi.com': 97},
#   3: {'amet.ornare.lectus@Pellentesquehabitantmorbi.co.uk': 83,
#    'orci.quis@dignissim.ca': 95,
#    'dui@enim.ca': 94,
#    'eu@Craseget.com': 73,
#    'aliquet.vel@Vestibulum.org': 84,
#    'at@massa.net': 92,
#    'in@iaculis.org': 80,
#    'porttitor.eros@ametdapibus.com': 96,
#    'orci.tincidunt.adipiscing@lobortisrisusIn.org': 94,
#    'Curabitur.egestas.nunc@erat.org': 93,
#    'ante.ipsum@Phasellusat.edu': 88,
#    'faucibus@elitNulla.edu': 82,
#    'Nunc.ullamcorper@aceleifend.net': 91,
#    'dolor.Quisque.tincidunt@quisarcuvel.com': 94,
#    'turpis@milorem.ca': 100,
#    'semper.auctor.Mauris@Maurismagna.com': 94,
#    'blandit@augue.ca': 96,
#    'tellus.imperdiet@necmetus.net': 84,
#    'dui.quis@pretiumneque.com': 78,
#    'tristique.aliquet.Phasellus@dictumeuplacerat.ca': 95,
#    'sit@duiSuspendisse.edu': 72,
#    'pede.Nunc.sed@justoProin.co.uk': 91,
#    'eu.ultrices.sit@tempuseu.ca': 88,
#    'Cras.pellentesque.Sed@ligulatortor.ca': 99,
#    'ut.nulla@Aliquam.edu': 91,
#    'sem.Nulla@lacuspedesagittis.co.uk': 98,
#    'Integer.tincidunt.aliquam@enim.ca': 94,
#    'convallis.convallis@facilisi.edu': 91,
#    'Etiam.laoreet.libero@amet.org': 80,
#    'pede@pharetrasedhendrerit.co.uk': 83,
#    'congue.a@eudoloregestas.edu': 87,
#    'gravida.Aliquam.tincidunt@nulla.ca': 99,
#    'vitae@Pellentesque.com': 74,
#    'inceptos@semperet.ca': 89,
#    'nec.cursus@arcuVestibulumante.net': 91,
#    'mauris.Morbi@aliquetnec.edu': 86,
#    'Donec.consectetuer.mauris@feugiat.co.uk': 89,
#    'ultricies.sem.magna@scelerisquenequeNullam.edu': 78,
#    'Nulla@atauctorullamcorper.com': 92,
#    'Nunc.laoreet@Aliquamrutrum.ca': 90,
#    'a@acarcuNunc.org': 63,
#    'Phasellus.fermentum@Proin.org': 86,
#    'dui.in.sodales@lorem.org': 99,
#    'nisl.Maecenas@justo.com': 84,
#    'volutpat@quis.com': 73,
#    'vitae.orci.Phasellus@turpis.com': 75,
#    'odio@nonmassa.net': 91,
#    'Phasellus.at.augue@eu.co.uk': 78,
#    'vel@enimnonnisi.com': 61,
#    'orci@purusDuiselementum.ca': 77,
#    'Pellentesque@eros.ca': 76,
#    'Mauris.non.dui@blanditatnisi.edu': 100,
#    'Fusce@vitae.ca': 89,
#    'malesuada.Integer@ornareplacerat.com': 85,
#    'id.ante@tellus.net': 91,
#    'sem.Nulla@at.edu': 95,
#    'ut.nulla.Cras@nisi.org': 96,
#    'enim.diam.vel@fringillamilacinia.co.uk': 98,
#    'et.commodo@elit.com': 65,
#    'nulla.Integer.urna@tortor.ca': 95,
#    'velit.Quisque@scelerisque.co.uk': 99,
#    'aliquet.sem@non.co.uk': 94,
#    'odio.Aliquam@rhoncus.ca': 71,
#    'non@Proinmi.edu': 92,
#    'lorem.fringilla.ornare@non.com': 89,
#    'ante@auctorMauris.edu': 63,
#    'ullamcorper.Duis.at@netus.org': 97,
#    'non.massa.non@Morbivehicula.org': 82,
#    'Maecenas.mi@Etiamvestibulum.ca': 83,
#    'Quisque.porttitor.eros@enimMauris.ca': 86,
#    'consequat.purus.Maecenas@eratSed.com': 82,
#    'mi@felis.edu': 87,
#    'orci@metus.edu': 49,
#    'aliquet.libero.Integer@lectussit.net': 85,
#    'vel@id.ca': 95,
#    'ipsum.sodales@purusmauris.edu': 36,
#    'ac@cubiliaCuraePhasellus.org': 98,
#    'Donec.dignissim@luctus.ca': 96,
#    'libero@sagittislobortismauris.net': 94,
#    'sed@quamquisdiam.edu': 87,
#    'eu.arcu.Morbi@Curabituregestasnunc.co.uk': 83,
#    'Proin@vitae.net': 72,
#    'magna.Sed.eu@loremlorem.ca': 92,
#    'Quisque@sitametnulla.co.uk': 82,
#    'malesuada.vel.venenatis@egetmagnaSuspendisse.com': 91,
#    'Nunc.laoreet@adlitora.net': 80,
#    'magnis.dis@fringillapurus.org': 97,
#    'quis@Suspendisse.net': 99,
#    'Proin.nisl.sem@DonectinciduntDonec.com': 97,
#    'aliquet.metus.urna@interdum.edu': 80,
#    'sem.semper.erat@mattissemper.net': 87,
#    'Fusce@risus.co.uk': 97,
#    'nonummy.Fusce.fermentum@luctussitamet.co.uk': 83,
#    'erat@auguemalesuada.net': 91,
#    'commodo.hendrerit.Donec@congueaaliquet.net': 6,
#    'et@turpisegestasAliquam.org': 71,
#    'diam.Proin.dolor@pretiumnequeMorbi.ca': 99,
#    'adipiscing.elit@eutellusPhasellus.edu': 96,
#    'cursus.a@feugiattelluslorem.edu': 76,
#    'adipiscing@lobortisnisi.com': 97}}}

# %% [markdown]
# # Outputting Online Grades Data
#
# Now we've processed the two data sources, and it's time to create a file that OGS will accept.  We can take a look at [the OGS documentation](https://registrar.mit.edu/sites/default/files/2018-12/ogs_import_instructions.pdf) to learn about the format.  It's based on a common convention called [CSV](https://en.wikipedia.org/wiki/Comma-separated_values), for Comma-Separated Values.  The convention is probably clear almost immediately after looking at the example data, and it's also easy to process with code, either handrolled or from a popular library.  Pretty much any popular spreadsheet program can load and save CSV files.
#
# It's not hard to write the code to output final grade information in our example.  The most serious gymnastics come from splitting a string with a student's name into first, middle, and last names.  First we write some manual code, coming back afterward to a shorter version using more of the Python standard library.
#
# Annoyingly, WebSIS gives student names as combined strings, while Online Grades wants separate last and first names and middle initials!  Let's write a function to make a best-effort decomposition.

# %%
def splitName(name):
    # These variables will store positions in the string.
    comma = None
    firstSpace = None
    secondSpace = None

    for i in range(len(name)):
        if name[i] == ',' and not comma:
            comma = i
        elif name[i] == ' ' and not firstSpace:
            firstSpace = i
        elif name[i] == ' ':
            secondSpace = i

    return name[:comma], name[firstSpace+1:secondSpace], name[secondSpace+1:secondSpace+2]

# %%
splitName('Doe, John Q.')
# Out:
# ('Doe', 'John', 'Q')

# %% [markdown]
# It turns out that there's a much simpler way to do this kind of string matching, using Python's standard library and an idea called _regular expressions_.

# %%
import re

def splitNameWithRegex(name):
    m = re.search("(.*), (.*) (.*)\\.", name)
    return m.group(1), m.group(2), m.group(3)

# %%
splitNameWithRegex('Doe, John Q.')
# Out:
# ('Doe', 'John', 'Q')

# %% [markdown]
# The next important ingredient is the one that actually computes the letter grade!  We need to compute percentages and map them to letters.

# %%
def averageToLetter(n):
    if n >= 90:
        return "A"
    elif n >= 80:
        return "B"
    elif n >= 70:
        return "C"
    elif n >= 60:
        return "D"
    else:
        return "A+"

# %% [markdown]
# To keep this simple, we'll weight all psets/quizzes equally.

# %%
def studentAverage(email, grades):
    total = 0

    for pset in grades["psets"].values():
        if email in pset:
            total += pset[email]

    for quiz in grades["quizzes"].values():
        if email in quiz:
            total += quiz[email]

    return total / (len(grades["psets"]) + len(grades["quizzes"]))

def studentGrade(email, grades):
    return averageToLetter(studentAverage(email, grades))

# %%
studentAverage('aliquet.vel@Vestibulum.org', grades)
# Out:
# 81.08333333333333

# %%
studentGrade('aliquet.vel@Vestibulum.org', grades)
# Out:
# 'B'

# %% [markdown]
# Now the end of our long journey: outputting the file suitable for OGS import.

# %%
def outputGrades(filename, students, grades):
    with open(filename, "w") as f:
        f.write("Last Name,First Name,Middle,MIT ID,Subject #,Section #,Grade,Units,Comment\n")

        for student in students:
            last, first, middle = splitName(student["Student Name"])
            f.write(last + "," + first + "," + middle + "," \
                    + student["MIT ID"] + "," \
                    + student["Enrolled"] + "," \
                    + student["Sec"] + "," \
                    + studentGrade(student["Email Address"], grades) + "," \
                    + student["Un"] + "," \
                    + "\n")

# %%
outputGrades('ogs.csv', websis, grades)

# %% [markdown]
# # Reading Multiple Input Files
#
# Sometimes data arrive as many files sitting in one directory.  In such cases, we need to be able to list all files in a directory, processing each one and combining the results somehow.  Consider the example of an alternative grades input format with one file per pset or quiz, found in generated subdirectory `grades`.  Each file is a CSV giving student e-mail addresses and numeric scores.  Our solution shows off more regular-expression operators.

# %%
import os

def parseCsvLine(line):
    """Parse one line of a CSV file, breaking it into a list of field values."""
    parts = []

    while True:
        m = re.search("([^,]*),(.*)", line)
        if not m:
            parts.append(line)
            return parts
        else:
            parts.append(m.group(1))
            line = m.group(2)

def readCsvFile(filename):
    """Read a whole CSV file that begins with a header line.
    Returns a list of dictionaries, with keys corresponding to header texts."""
    
    students = []

    with open(filename, "r") as f:
        headers = parseCsvLine(f.readline())

        for line in f:
            parts = parseCsvLine(line)
            student = {headers[i]: parts[i] for i in range(len(headers))}
            students.append(student)

        return students

def readMultiFile(dirname):
    """Read all CSV files in a directory, to produce a grades database
    of the kind we built above."""
    
    out = {"psets": {},
           "quizzes": {}}

    for filename in os.listdir(dirname):
        lines = readCsvFile(os.path.join(dirname, filename))
        mapping = {line["Email Address"]: int(line["Grade"]) for line in lines}

        m = re.search("pset([0-9]*)\\.csv", filename)
        if m:
            out["psets"][int(m.group(1))] = mapping
        else:
            m = re.search("quiz([0-9]*)\\.csv", filename)
            if m:
                out["quizzes"][int(m.group(1))] = mapping

    return out

# %%
readMultiFile('grades')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-a1d25e584c45> in <module>
# ----> 1 readMultiFile('grades')
#
# <ipython-input-26-390fecc1dd11> in readMultiFile(dirname)
#      37            "quizzes": {}}
#      38
# ---> 39     for filename in os.listdir(dirname):
#      40         lines = readCsvFile(os.path.join(dirname, filename))
#      41         mapping = {line["Email Address"]: int(line["Grade"]) for line in lines}
#
# FileNotFoundError: [Errno 2] No such file or directory: 'grades'

# %% [markdown]
# # Writing Multiple Output Files
#
# The last example generates output as multiple files in a fresh directory, giving each student a text file listing all grades.  This code relies on very few new tricks.

# %%
def makeStudentReports(dirname, students, grades):
    """Given values representing student data and grades, create the specified directory
    and populate it with one textual grade report per student."""
    os.mkdir(dirname)

    for student in students:
        with open(os.path.join(dirname, student["MIT ID"] + ".txt"), "w") as f:
            f.write("Dear " + student["Student Name"] + ",\n")
            f.write("\n")
            f.write("How are you enjoying Course " + student["Course"] + "?  Here are your grades in 6.666.\n")
            f.write("\n")

            f.write("Psets:\n")
            for pset, scores in grades["psets"].items():
                if student["Email Address"] in scores:
                    f.write("#" + str(pset) + ": " + str(scores[student["Email Address"]]) + "\n")
            f.write("\n")

            f.write("Quizzes:\n")
            for quiz, scores in grades["quizzes"].items():
                if student["Email Address"] in scores:
                    f.write("#" + str(quiz) + ": " + str(scores[student["Email Address"]]) + "\n")

# %%
makeStudentReports('reports', websis, grades)

# %% [markdown]
# # Summary
#
# Our coordinated suite of examples illustrates a number of practical points about working with real-world datasets:
#  1. The same data could arrive in many different formats.
#  2. There are many different ways of remixing the same underlying data.
#  3. The same results can be output in many different ways.
#
# When we have to deal with a change in just one of these three aspects, it's very convenient to be able to reuse our code for the others, which suggests how important is to use standard data-structure formats internally.
